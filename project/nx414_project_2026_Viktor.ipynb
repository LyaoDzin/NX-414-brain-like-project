# %% [markdown]
# <div style="background: linear-gradient(135deg, #e9f2fb 0%, #f7fbff 100%); padding: 18px 20px; border: 1px solid #d5e3f0; border-radius: 10px; text-align: center;">
#   <div style="font-size: 32px; font-weight: 700; color: #1f3b57; letter-spacing: 0.2px;">NX-414 Brain-like Computation and Intelligence</div>
# </div>

# %% [markdown]
# <div style="text-align: center; font-size: 21px; font-weight: 600; color: #36536b; margin-top: 6px;">Project Notebook — Spring 2026</div>

# %% [markdown]
# <div style="text-align: center; color: #4f6478; font-size: 16px; margin-bottom: 10px;">Brain–Model Alignment Across Neural Recording Modalities</div>
# <div style="text-align: center; color: #6b7280; font-size: 13px;">Prepared by: Abdulkadir Gokce</div>
#
# ---

# %% [markdown]
# # Group Information
#
# Fill in this section at the top of your notebook and report.
# FINISH !!!!!!!
# - **Group member 1:** Olga Liubmova
# - **Group member 2:** Full name, SCIPER number, email address
# - **Group member 3 (if applicable):** Full name, SCIPER number, email address
#
# ---

# %% [markdown]
# # What You Must Submit
#
# Submit the following files:
#
# 1. **One Jupyter notebook** containing your full analysis.
# 2. **Any supporting Python scripts** needed to run the notebook.
# 3. **Figures that are part of your notebook answers** should be embedded and rendered in notebook Markdown.
# 4. **One PDF report** of **up to 2 pages**, **excluding references**, with **no appendix**.
# 5. **One zip archive** named exactly as:

# %% [markdown]
# ```text
# nx414_{SCIPER1}_{SCIPER2}_{SCIPER3}.zip
# ```

# %% [markdown]
# If your group has fewer than three members, reduce the number of `_SCIPER` fields accordingly.

# %% [markdown]
# ## Submission Rules
#
# - **Clear all notebook outputs before submission.**
# - If outputs are not cleared, we will clear them ourselves and grade the cleaned notebook.
# - Submit only the code required to reproduce your results.
# - **Do not submit model weights.**
# - **Do not submit CSV files or other large derived result dumps.**
# - Keep the archive lightweight and reproducible.
# - For the **final notebook**, any figure you want to present as part of your scientific argument should be **embedded in Markdown with accompanying interpretation**, rather than left as a raw cell output with no explanation.
#
# Failure to follow these instructions may reduce your final grade.

# %% [markdown]
# ## Use of LLMs
#
# You may use LLM-based tools to help you write code, debug, or improve explanations. However, you remain fully responsible for the **correctness**, **quality**, and **clarity** of everything you submit, including both the notebook and the report.
#
# In particular:
#
# - check that any generated code actually runs and does what you claim it does,
# - verify that any scientific statement or interpretation is correct,
# - make sure the final writing sounds like a clear academic report written for this course,
# - avoid vague, overly polished, or context-free text,
# - avoid fancy wording or unnecessarily complex sentences that do not add clarity.
#
# If you use an LLM, revise the output so that your submission reads naturally, is specific to your actual results, and does not look like generic generated text.
#
# Failure to do so may result in **a point deduction**.

# %% [markdown]
# ## Expected scope
#
# Because this project spans roughly **three weeks** and counts for **30% of the final course grade**, the expected output is closer to a **compact course project** than to a one-week homework notebook. Your submission should therefore read like a small empirical study: it should be clearly structured, contain short written interpretations throughout, compare alternatives systematically, and end with a coherent synthesis of your main findings.
#
# A strong notebook will not only run end-to-end, but will also explain **why** each analysis is being performed, what each metric is meant to capture, and what the results imply about the strengths and limitations of the models and datasets.
#
# At the same time, **some parts of the project are intentionally left a bit loose**. This is by design: beyond implementing the required core analyses, you are expected to make reasonable scientific choices, justify them clearly, and show some ingenuity in how you explore the data and compare models.

# %% [markdown]
# ## Suggested 3-week pacing
#
# Use the notebook structure below to organize your work over the three weeks.
#
# - **Week 1:** complete **Section 0** and **Section 1**. Understand the datasets, verify stimulus matching, inspect the processed responses, and start the visualization and reliability analyses.
# - **Week 2:** complete the required analyses in **Section 2**. In this section, you must complete both the representational and predictive parts of the project. Begin **Section 3** by brainstorming possible extensions and sketching out a plan for your chosen extension.
# - **Week 3:** complete **Section 3**, polish the notebook, select the strongest figures, and write the 2-page report.
#
#
# ---

# %% [markdown]
# # 0. Introduction and Setup

# %% [markdown]
# ## 0.1 Project goal
#
# In this project, you will study how neural responses from different recording modalities align with features extracted from two vision models. More specifically, you will work in the standard **brain–model alignment** setting: a model processes an image, a candidate internal layer is selected, and that representation is compared to measured neural responses using representational and predictive metrics.
#
# The notebook is organized around four sections:
#
# - **Section 0:** introduction, setup, and understanding the provided resources.
# - **Section 1:** dataset inspection, visualization, and noise ceiling estimation.
# - **Section 2:** brain–model alignment through both representational metrics and predictive linear models.
# - **Section 3:** an open-ended extension beyond the baseline pipeline.

# %% [markdown]
# ## 0.2 Why task-optimized models?
#
# Task-optimized neural networks are among the most useful current **in-silico models of sensory cortex**. The central idea is simple: instead of hand-designing a model to mimic every biological detail, we optimize a model to perform a meaningful visual task and then ask whether its internal representations resemble those found in the brain. This approach has been highly influential because models trained to solve vision tasks often develop representations that predict activity along the visual hierarchy surprisingly well.
#
# These models are useful scientifically because they provide **testable computational hypotheses**. If a model layer predicts neural responses well, that does not mean the brain literally implements the same mechanism, but it does suggest that the layer may encode information in a similar format or at a similar level of abstraction. Brain–model alignment is therefore a way to ask not just whether a model is accurate on a task, but whether it organizes visual information in a brain-relevant way.

# %% [markdown]
# ## 0.3 Why compare multiple modalities?
#
# A single recording modality gives only a partial view of neural computation. In this project, you will work with **electrophysiology, EEG, and fMRI**, which differ in temporal resolution, spatial resolution, and what exactly is measured. Looking across modalities helps you see which conclusions are robust and which depend on the measurement scale.

# %% [markdown]
# ## 0.4 Learning goals
#
# By the end of this project, you should be able to:
#
# - inspect and summarize neural datasets from multiple modalities,
# - visualize neural signals and data quality,
# - implement and compare **two noise ceiling estimators**,
# - implement **RSA** and **unbiased linear CKA**,
# - fit **linear encoding models** from model features to neural responses,
# - compare alignment across **models, layers, ROIs, and metrics**,
# - interpret what each alignment metric captures,
# - design and evaluate one meaningful extension beyond the baseline pipeline.
#
# A strong submission should therefore demonstrate both **technical correctness** and **scientific reasoning**: beyond obtaining scores, you should be able to explain why a dataset is noisy, why one layer may outperform another, and why representational and predictive metrics sometimes disagree.

# %% [markdown]
# ## 0.5 Provided data
#
# All main data are stored in `/shared/NX-414/data/`.

# %% [markdown]
# ### Background: processed data derivatives
#
# The files provided for this project are **not raw neural recordings**. They are already processed, analysis-ready derivatives produced with modality-appropriate pipelines. This is important scientifically: many of your results will depend not only on the model features, but also on preprocessing choices such as repetition averaging, denoising, response-window selection, voxel/channel filtering, and how reliability is estimated.
#
# We performed the preprocessing for you because these pipelines often require substantial modality-specific expertise, time, and compute.
#
# At a high level, the datasets used here were prepared as follows:
#
# - **TVSD (macaque electrophysiology)** — normalized multi-unit responses from ventral-stream areas. Responses were z-scored within session, firing rates were averaged in an analysis window centered on each site’s response peak, low-reliability channels were excluded, and repeated test responses were averaged for evaluation.
# - **THINGS-EEG2 (human EEG)** — source EEG responses resampled to **100 Hz**. Noise ceilings were computed per subject, channel, and time point, and repetitions were averaged within train and test splits.
# - **NSD (human fMRI)** — **b3 single-trial beta estimates** in `func1pt8mm` space, derived using voxel-wise HRF fitting, GLMdenoise, and ridge regression. Analyses are restricted to ROI-defined visually responsive voxels, low-reliability voxels are filtered out, and responses are averaged across available repetitions.
#
# You are **not** expected to re-run the full preprocessing pipelines. You **are** expected to understand what kinds of neural quantities you are analyzing, what has already been averaged or denoised, and how these choices affect interpretation.

# %% [markdown]
# ### Main neural datasets
#
# - **`tvsd.h5`** — macaque electrophysiology from **2 monkeys**, with **22,248 train** and **100 test** stimuli, covering **V1, V4, and IT**.
# - **`things_eeg2.h5`** — human EEG from **10 subjects**, with **16,540 train** and **200 test** stimuli, with region groupings such as **occipital**, **parietal**, **temporal**, **frontal**, **central**, **occipital_parietal**, and **whole_brain**.
# - **`nsd_func1pt8mm_individualROIs.h5`** — human fMRI from **8 subjects**, with roughly **9,000 train** and **1,000 test** stimuli per subject, across multiple visual ROIs.

# %% [markdown]
# ### Additional files
#
# - `things_eeg2-test_reps.h5`
#   EEG test responses **with repetitions and without averaging**.
#   Use this file to implement and compare **two noise ceiling estimators**.
#
# - `nsd-subj01-ncsnr-{lh,rh}.mgh`
#   Surface-based NSD reliability values for `subj-01` on **fsaverage**.
#   Use these to visualize cortical reliability and convert **ncsnr** into **noise ceiling**.

# %% [markdown]
# ### Neural response shapes
#
# - **TVSD:** `(n_stimuli, n_units)`
# - **EEG2:** `(n_stimuli, n_channels, n_timepoints)`
# - **NSD:** `(n_stimuli, n_voxels)`
#
# For EEG, the time axis contains **80 time points** sampled at **100 Hz**, covering **0.0 s to 0.8 s**.

# %% [markdown]
# ### Noise ceilings
#
# Noise ceilings are stored per target:
#
# - per neuron for **TVSD**,
# - per channel × time point for **EEG2**,
# - per voxel for **NSD**.
#
# They are stored as **percent reliability**.
# To convert them to the range `[0, 1]`, divide by `100`.
#
# In this project, the provided noise ceilings are mainly intended for **predictive metrics** such as **Pearson correlation** and **explained variance**. They reflect the reliability of the neural responses and therefore define an upper bound on how well any model can predict those responses.
#
# When you compute predictive metrics, you should apply a noise ceiling correction to account for this upper bound. The standard idea is simple: divide the raw predictive score by the corresponding noise ceiling value for that target.
#
# The provided noise ceilings are defined for **explained variance**. If you want to apply the same logic to **Pearson correlation**, first convert the explained-variance ceiling into a correlation ceiling by taking the element-wise square root, and then divide the raw correlation by that quantity. For a more detailed discussion of noise ceiling correction, see van Bree et al. (2025).
#
# You may therefore report both **raw** and **noise-ceiling-corrected** predictive scores where appropriate.
#
#
# For example, if the provided ceiling is an explained-variance reliability estimate, you can compute a noise-corrected Pearson correlation as:
#
# ```python
# r_nc = r / np.sqrt(ev_ceiling)
# ```
#
# where `r` is the raw Pearson correlation and `ev_ceiling` is the explained-variance ceiling expressed on the range `[0, 1]`.
#
# By contrast, **RSA** and **CKA** should typically be reported as **raw values** in this project. Noise ceilings for representational similarity metrics require a different methodology and are **not** provided here.

# %% [markdown]
# Do **not** apply this correction directly to **RSA** or **CKA**.

# %% [markdown]
# ### Stimulus identifiers
#
# - **TVSD / EEG2:** byte strings such as `b'aardvark/aardvark_01b.jpg'`
# - **NSD:** integer stimulus IDs

# %% [markdown]
# ## 0.6 Model features
#
# All extracted features are stored in `/shared/NX-414/extracted_features/`.
#
# The feature files contain **internal activations extracted from multiple candidate layers** while the models process the same images shown in the neural experiments. You can think of each layer as a representation matrix of shape roughly **stimuli × features**. These layer-wise representations are what you will compare to the brain using RSA, CKA, and encoding models.
#
# Feature extractions across models were made tractable by projecting activations to **30,000 dimensions** using a random projection. The provided feature files follow that same idea. In practice, this means you can treat the feature vectors as compact surrogates for the original activations while still performing meaningful alignment analyses.

# %% [markdown]
# ### Model A: `adv_resnet152_imagenet_full_ffgsm_eps-1_alpha-125-ep10_seed-0`
#
# - Architecture: **ResNet-152**
# - Pretraining: ImageNet + adversarial fine-tuning
# - Available feature files:
#   - `things_stimuli.h5`
#   - `nsd_stimuli.h5`

# %% [markdown]
# ### Model B: `Qwen3-VL-2B-Instruct`
#
# - Architecture: **vision-language transformer**
# - Available feature files:
#   - `things_stimuli.h5`
#   - `nsd_stimuli.h5`
#
# For both models, layers have been projected to **30,000 dimensions** using random projections.

# %% [markdown]
# ### Feature extraction note
#
# For this project, feature extraction has already been done for you. Your job is therefore not to run the vision models on raw images, but to understand **which layer** to use, how to match feature rows to neural stimuli, and what different layers reveal about representational hierarchy.

# %% [markdown]
# ### Important note for NSD
#
# For NSD, the feature files contain features for **all 73,000 images**, but each subject saw only a subset (~9,000).
# You must therefore select feature rows using the subject-specific NSD stimulus IDs.

# %% [markdown]
# ## 0.7 Matching features to neural responses
#
# You must match neural responses and features through the stimulus IDs.

# %% [markdown]
# ### THINGS-based datasets: TVSD and EEG2
#
# For these datasets, both neural IDs and feature IDs are byte strings. Matching should therefore be exact.

# %% [markdown]
# ### NSD
#
# For NSD, both sides use integer IDs. The feature file contains all 73,000 stimuli, while each subject has only a subset. Use the subject-specific NSD stimulus IDs to select the corresponding feature rows.

# %% [markdown]
# ### Recommended procedure

# %% [markdown]
# ```python
# feat_ids = feature_file['ids'][:]
# id_to_feat_idx = {id_: i for i, id_ in enumerate(feat_ids)}
# feat_idx = np.array([id_to_feat_idx[x] for x in neural_ids])
# ```

# %% [markdown]
# To make HDF5 reads efficient:
#
# 1. build the index array,
# 2. sort indices before reading,
# 3. load only the required rows,
# 4. restore the original order.

# %% [markdown]
# ## 0.8 General analysis rules

# %% [markdown]
# ### Train/test discipline
#
# Do **not** use the test split for model selection or hyperparameter tuning. Use a validation split or cross-validation within the training data.

# %% [markdown]
# ### EEG targets
#
# For EEG, you may either:
#
# - flatten the targets to `(n_stimuli, n_channels * n_timepoints)`, or
# - fit separate models per channel × time point.
#
# Either choice is acceptable, but you must explain your decision clearly.

# %% [markdown]
# ### Predictive metrics
#
# Report the following predictive metrics where appropriate:
#
# - `pearsonr`
# - `pearsonr_nc`
# - `explained_variance`
# - `explained_variance_nc`
#
# The provided EEG signals are not filtered like the other datasets. As a result, some low-reliability channels or time points can produce unstable predictive scores. When averaging predictive metrics over EEG targets, apply an on-the-fly filter such as **noise ceiling < 0.1**.

# %% [markdown]
# ### Representational metrics
#
# Also report:
#
# - `RSA`
# - `CKA`
# - `encoding-RSA`
# - `encoding-CKA`
#
# Encoding RSA/CKA is a hybrid metric where you compute RSA or CKA between the predicted neural responses (from the linear encoding model) and the actual neural responses, instead of just comparing model activation directly. This can help you understand whether the linear encoding model captures the representational geometry of the neural data, beyond just predicting individual response values. You can refer to Conwell et al. (2024) for more details on this approach.
#
# Use only the test split for computing representational metrics.
#
# Do **not** noise-correct RSA or CKA using the predictive-metric procedure.

# %% [markdown]
# ## 0.9 Setup and data loading
#
# Your notebook should begin with a short introduction, clear imports, utility functions, and a brief verification that the provided files are correctly organized and matched.
#
# **Section 0 is required but not graded separately.** It is treated as setup for the rest of the project. Missing or incorrect setup may reduce scores in later sections if it affects correctness or reproducibility.

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - Import the required packages.
# - Define utility functions.
# - Load metadata for all datasets.
# - Inspect the structure of each `.h5` file.
# - Load feature metadata for both models.
# - Verify that feature IDs and neural stimulus IDs match.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **Dataset and feature overview:** one compact table or printed summary covering all neural datasets and both feature sets.
# 2. **Stimulus-matching verification:** explicit checks or assertions showing that stimulus matching works for THINGS-based datasets and for NSD.
# 3. **Short structural summary:** a short written note describing the main structural differences across datasets.

# %% [markdown]
# <div style="background:#eef8f4; border-left:4px solid #5b9a7a; padding:8px 12px; border-radius:6px; font-weight:700; color:#285943;">Questions you should answer</div>
#
# - How many stimuli are available in each dataset?
# - What is the shape of the neural response tensor in each dataset?
# - Which datasets contain subjects, ROIs, repetitions, channels, or time points?
# - What are the feature dimensionalities across layers?
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 0</strong><br>Summarize the structure of the three datasets and the two feature sets in 4–6 sentences. Clearly state which dataset is most complex structurally and why.</div>

# %%
# TODO: imports
# TODO: define paths
# TODO: inspect dataset structure
# TODO: verify stimulus matching

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm
from sklearn import metrics
from scipy import stats
import nibabel as nib
from nilearn import plotting as nlplt
import h5py
import torch

# %%
import h5py
import numpy as np

print ("\nLoading TVSD\n")
# Load TVSD (macaque electrophysiology)
with h5py.File('/shared/NX-414/data/tvsd.h5', 'r') as f:
    def print_structure(name, obj):
        print(name, '->', type(obj).__name__, getattr(obj, 'shape', ''))
    f.visititems(print_structure)

print ("\nLoading EEG\n")
with h5py.File('/shared/NX-414/data/things_eeg2.h5', 'r') as f:
    def print_structure(name, obj):
        print(name, '->', type(obj).__name__, getattr(obj, 'shape', ''))
    f.visititems(print_structure)


print ("\nLoading fMRI\n")
# Load fMRI
with h5py.File('/shared/NX-414/data/nsd_func1pt8mm_individualROIs.h5', 'r') as f:
    def print_structure(name, obj):
        print(name, '->', type(obj).__name__, getattr(obj, 'shape', ''))
    f.visititems(print_structure)
# Out:
# Loading TVSD
#
# noise_ceilings -> Group
# noise_ceilings/monkeyF -> Group
# noise_ceilings/monkeyF/IT -> Dataset (241,)
# noise_ceilings/monkeyF/V1 -> Dataset (462,)
# noise_ceilings/monkeyF/V4 -> Dataset (139,)
# noise_ceilings/monkeyN -> Group
# noise_ceilings/monkeyN/IT -> Dataset (178,)
# noise_ceilings/monkeyN/V1 -> Dataset (437,)
# noise_ceilings/monkeyN/V4 -> Dataset (247,)
# test -> Group
# test/neural_data -> Group
# test/neural_data/monkeyF -> Group
# test/neural_data/monkeyF/IT -> Dataset (100, 241)
# test/neural_data/monkeyF/V1 -> Dataset (100, 462)
# test/neural_data/monkeyF/V4 -> Dataset (100, 139)
# test/neural_data/monkeyN -> Group
# test/neural_data/monkeyN/IT -> Dataset (100, 178)
# test/neural_data/monkeyN/V1 -> Dataset (100, 437)
# test/neural_data/monkeyN/V4 -> Dataset (100, 247)
# test/stimulus_ids -> Dataset (100,)
# train -> Group
# train/neural_data -> Group
# train/neural_data/monkeyF -> Group
# train/neural_data/monkeyF/IT -> Dataset (22248, 241)
# train/neural_data/monkeyF/V1 -> Dataset (22248, 462)
# train/neural_data/monkeyF/V4 -> Dataset (22248, 139)
# train/neural_data/monkeyN -> Group
# train/neural_data/monkeyN/IT -> Dataset (22248, 178)
# train/neural_data/monkeyN/V1 -> Dataset (22248, 437)
# train/neural_data/monkeyN/V4 -> Dataset (22248, 247)
# train/stimulus_ids -> Dataset (22248,)
#
# Loading EEG
#
# noise_ceilings -> Group
# noise_ceilings/sub-01 -> Group
# noise_ceilings/sub-01/central -> Dataset (14, 80)
# noise_ceilings/sub-01/frontal -> Dataset (21, 80)
# noise_ceilings/sub-01/occipital -> Dataset (3, 80)
# noise_ceilings/sub-01/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-01/parietal -> Dataset (14, 80)
# noise_ceilings/sub-01/temporal -> Dataset (6, 80)
# noise_ceilings/sub-01/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-02 -> Group
# noise_ceilings/sub-02/central -> Dataset (14, 80)
# noise_ceilings/sub-02/frontal -> Dataset (21, 80)
# noise_ceilings/sub-02/occipital -> Dataset (3, 80)
# noise_ceilings/sub-02/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-02/parietal -> Dataset (14, 80)
# noise_ceilings/sub-02/temporal -> Dataset (6, 80)
# noise_ceilings/sub-02/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-03 -> Group
# noise_ceilings/sub-03/central -> Dataset (14, 80)
# noise_ceilings/sub-03/frontal -> Dataset (21, 80)
# noise_ceilings/sub-03/occipital -> Dataset (3, 80)
# noise_ceilings/sub-03/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-03/parietal -> Dataset (14, 80)
# noise_ceilings/sub-03/temporal -> Dataset (6, 80)
# noise_ceilings/sub-03/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-04 -> Group
# noise_ceilings/sub-04/central -> Dataset (14, 80)
# noise_ceilings/sub-04/frontal -> Dataset (21, 80)
# noise_ceilings/sub-04/occipital -> Dataset (3, 80)
# noise_ceilings/sub-04/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-04/parietal -> Dataset (14, 80)
# noise_ceilings/sub-04/temporal -> Dataset (6, 80)
# noise_ceilings/sub-04/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-05 -> Group
# noise_ceilings/sub-05/central -> Dataset (14, 80)
# noise_ceilings/sub-05/frontal -> Dataset (21, 80)
# noise_ceilings/sub-05/occipital -> Dataset (3, 80)
# noise_ceilings/sub-05/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-05/parietal -> Dataset (14, 80)
# noise_ceilings/sub-05/temporal -> Dataset (6, 80)
# noise_ceilings/sub-05/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-06 -> Group
# noise_ceilings/sub-06/central -> Dataset (14, 80)
# noise_ceilings/sub-06/frontal -> Dataset (21, 80)
# noise_ceilings/sub-06/occipital -> Dataset (3, 80)
# noise_ceilings/sub-06/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-06/parietal -> Dataset (14, 80)
# noise_ceilings/sub-06/temporal -> Dataset (6, 80)
# noise_ceilings/sub-06/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-07 -> Group
# noise_ceilings/sub-07/central -> Dataset (14, 80)
# noise_ceilings/sub-07/frontal -> Dataset (21, 80)
# noise_ceilings/sub-07/occipital -> Dataset (3, 80)
# noise_ceilings/sub-07/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-07/parietal -> Dataset (14, 80)
# noise_ceilings/sub-07/temporal -> Dataset (6, 80)
# noise_ceilings/sub-07/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-08 -> Group
# noise_ceilings/sub-08/central -> Dataset (14, 80)
# noise_ceilings/sub-08/frontal -> Dataset (21, 80)
# noise_ceilings/sub-08/occipital -> Dataset (3, 80)
# noise_ceilings/sub-08/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-08/parietal -> Dataset (14, 80)
# noise_ceilings/sub-08/temporal -> Dataset (6, 80)
# noise_ceilings/sub-08/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-09 -> Group
# noise_ceilings/sub-09/central -> Dataset (14, 80)
# noise_ceilings/sub-09/frontal -> Dataset (21, 80)
# noise_ceilings/sub-09/occipital -> Dataset (3, 80)
# noise_ceilings/sub-09/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-09/parietal -> Dataset (14, 80)
# noise_ceilings/sub-09/temporal -> Dataset (6, 80)
# noise_ceilings/sub-09/whole_brain -> Dataset (63, 80)
# noise_ceilings/sub-10 -> Group
# noise_ceilings/sub-10/central -> Dataset (14, 80)
# noise_ceilings/sub-10/frontal -> Dataset (21, 80)
# noise_ceilings/sub-10/occipital -> Dataset (3, 80)
# noise_ceilings/sub-10/occipital_parietal -> Dataset (17, 80)
# noise_ceilings/sub-10/parietal -> Dataset (14, 80)
# noise_ceilings/sub-10/temporal -> Dataset (6, 80)
# noise_ceilings/sub-10/whole_brain -> Dataset (63, 80)
# noise_ceilings_train -> Group
# noise_ceilings_train/sub-01 -> Group
# noise_ceilings_train/sub-01/central -> Dataset (14, 80)
# noise_ceilings_train/sub-01/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-01/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-01/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-01/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-01/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-01/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-02 -> Group
# noise_ceilings_train/sub-02/central -> Dataset (14, 80)
# noise_ceilings_train/sub-02/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-02/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-02/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-02/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-02/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-02/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-03 -> Group
# noise_ceilings_train/sub-03/central -> Dataset (14, 80)
# noise_ceilings_train/sub-03/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-03/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-03/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-03/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-03/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-03/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-04 -> Group
# noise_ceilings_train/sub-04/central -> Dataset (14, 80)
# noise_ceilings_train/sub-04/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-04/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-04/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-04/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-04/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-04/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-05 -> Group
# noise_ceilings_train/sub-05/central -> Dataset (14, 80)
# noise_ceilings_train/sub-05/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-05/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-05/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-05/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-05/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-05/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-06 -> Group
# noise_ceilings_train/sub-06/central -> Dataset (14, 80)
# noise_ceilings_train/sub-06/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-06/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-06/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-06/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-06/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-06/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-07 -> Group
# noise_ceilings_train/sub-07/central -> Dataset (14, 80)
# noise_ceilings_train/sub-07/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-07/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-07/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-07/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-07/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-07/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-08 -> Group
# noise_ceilings_train/sub-08/central -> Dataset (14, 80)
# noise_ceilings_train/sub-08/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-08/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-08/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-08/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-08/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-08/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-09 -> Group
# noise_ceilings_train/sub-09/central -> Dataset (14, 80)
# noise_ceilings_train/sub-09/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-09/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-09/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-09/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-09/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-09/whole_brain -> Dataset (63, 80)
# noise_ceilings_train/sub-10 -> Group
# noise_ceilings_train/sub-10/central -> Dataset (14, 80)
# noise_ceilings_train/sub-10/frontal -> Dataset (21, 80)
# noise_ceilings_train/sub-10/occipital -> Dataset (3, 80)
# noise_ceilings_train/sub-10/occipital_parietal -> Dataset (17, 80)
# noise_ceilings_train/sub-10/parietal -> Dataset (14, 80)
# noise_ceilings_train/sub-10/temporal -> Dataset (6, 80)
# noise_ceilings_train/sub-10/whole_brain -> Dataset (63, 80)
# test -> Group
# test/neural_data -> Group
# test/neural_data/sub-01 -> Group
# test/neural_data/sub-01/central -> Dataset (200, 14, 80)
# test/neural_data/sub-01/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-01/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-01/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-01/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-01/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-01/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-02 -> Group
# test/neural_data/sub-02/central -> Dataset (200, 14, 80)
# test/neural_data/sub-02/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-02/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-02/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-02/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-02/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-02/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-03 -> Group
# test/neural_data/sub-03/central -> Dataset (200, 14, 80)
# test/neural_data/sub-03/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-03/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-03/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-03/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-03/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-03/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-04 -> Group
# test/neural_data/sub-04/central -> Dataset (200, 14, 80)
# test/neural_data/sub-04/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-04/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-04/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-04/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-04/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-04/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-05 -> Group
# test/neural_data/sub-05/central -> Dataset (200, 14, 80)
# test/neural_data/sub-05/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-05/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-05/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-05/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-05/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-05/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-06 -> Group
# test/neural_data/sub-06/central -> Dataset (200, 14, 80)
# test/neural_data/sub-06/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-06/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-06/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-06/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-06/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-06/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-07 -> Group
# test/neural_data/sub-07/central -> Dataset (200, 14, 80)
# test/neural_data/sub-07/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-07/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-07/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-07/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-07/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-07/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-08 -> Group
# test/neural_data/sub-08/central -> Dataset (200, 14, 80)
# test/neural_data/sub-08/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-08/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-08/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-08/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-08/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-08/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-09 -> Group
# test/neural_data/sub-09/central -> Dataset (200, 14, 80)
# test/neural_data/sub-09/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-09/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-09/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-09/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-09/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-09/whole_brain -> Dataset (200, 63, 80)
# test/neural_data/sub-10 -> Group
# test/neural_data/sub-10/central -> Dataset (200, 14, 80)
# test/neural_data/sub-10/frontal -> Dataset (200, 21, 80)
# test/neural_data/sub-10/occipital -> Dataset (200, 3, 80)
# test/neural_data/sub-10/occipital_parietal -> Dataset (200, 17, 80)
# test/neural_data/sub-10/parietal -> Dataset (200, 14, 80)
# test/neural_data/sub-10/temporal -> Dataset (200, 6, 80)
# test/neural_data/sub-10/whole_brain -> Dataset (200, 63, 80)
# test/stimulus_ids -> Dataset (200,)
# train -> Group
# train/neural_data -> Group
# train/neural_data/sub-01 -> Group
# train/neural_data/sub-01/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-01/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-01/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-01/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-01/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-01/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-01/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-02 -> Group
# train/neural_data/sub-02/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-02/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-02/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-02/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-02/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-02/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-02/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-03 -> Group
# train/neural_data/sub-03/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-03/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-03/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-03/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-03/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-03/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-03/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-04 -> Group
# train/neural_data/sub-04/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-04/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-04/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-04/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-04/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-04/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-04/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-05 -> Group
# train/neural_data/sub-05/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-05/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-05/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-05/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-05/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-05/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-05/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-06 -> Group
# train/neural_data/sub-06/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-06/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-06/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-06/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-06/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-06/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-06/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-07 -> Group
# train/neural_data/sub-07/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-07/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-07/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-07/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-07/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-07/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-07/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-08 -> Group
# train/neural_data/sub-08/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-08/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-08/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-08/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-08/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-08/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-08/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-09 -> Group
# train/neural_data/sub-09/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-09/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-09/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-09/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-09/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-09/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-09/whole_brain -> Dataset (16540, 63, 80)
# train/neural_data/sub-10 -> Group
# train/neural_data/sub-10/central -> Dataset (16540, 14, 80)
# train/neural_data/sub-10/frontal -> Dataset (16540, 21, 80)
# train/neural_data/sub-10/occipital -> Dataset (16540, 3, 80)
# train/neural_data/sub-10/occipital_parietal -> Dataset (16540, 17, 80)
# train/neural_data/sub-10/parietal -> Dataset (16540, 14, 80)
# train/neural_data/sub-10/temporal -> Dataset (16540, 6, 80)
# train/neural_data/sub-10/whole_brain -> Dataset (16540, 63, 80)
# train/stimulus_ids -> Dataset (16540,)
#
# Loading fMRI
#
# noise_ceiling_full -> Group
# noise_ceiling_full/subj01 -> Dataset (81, 104, 83)
# noise_ceiling_full/subj02 -> Dataset (82, 106, 84)
# noise_ceiling_full/subj03 -> Dataset (81, 106, 82)
# noise_ceiling_full/subj04 -> Dataset (85, 99, 80)
# noise_ceiling_full/subj05 -> Dataset (79, 97, 78)
# noise_ceiling_full/subj06 -> Dataset (85, 113, 83)
# noise_ceiling_full/subj07 -> Dataset (78, 95, 81)
# noise_ceiling_full/subj08 -> Dataset (80, 103, 78)
# noise_ceilings -> Group
# noise_ceilings/subj01 -> Group
# noise_ceilings/subj01/EBA -> Dataset (2078,)
# noise_ceilings/subj01/FBA-1 -> Dataset (339,)
# noise_ceilings/subj01/FBA-2 -> Dataset (255,)
# noise_ceilings/subj01/FFA-1 -> Dataset (423,)
# noise_ceilings/subj01/FFA-2 -> Dataset (173,)
# noise_ceilings/subj01/OFA -> Dataset (283,)
# noise_ceilings/subj01/OPA -> Dataset (1353,)
# noise_ceilings/subj01/OWFA -> Dataset (369,)
# noise_ceilings/subj01/PPA -> Dataset (604,)
# noise_ceilings/subj01/RSC -> Dataset (362,)
# noise_ceilings/subj01/V1d -> Dataset (727,)
# noise_ceilings/subj01/V1v -> Dataset (570,)
# noise_ceilings/subj01/V2d -> Dataset (557,)
# noise_ceilings/subj01/V2v -> Dataset (725,)
# noise_ceilings/subj01/V3d -> Dataset (505,)
# noise_ceilings/subj01/V3v -> Dataset (554,)
# noise_ceilings/subj01/VWFA-1 -> Dataset (666,)
# noise_ceilings/subj01/VWFA-2 -> Dataset (281,)
# noise_ceilings/subj01/early -> Dataset (3952,)
# noise_ceilings/subj01/hV4 -> Dataset (578,)
# noise_ceilings/subj01/lateral -> Dataset (2161,)
# noise_ceilings/subj01/midlateral -> Dataset (735,)
# noise_ceilings/subj01/midparietal -> Dataset (692,)
# noise_ceilings/subj01/midventral -> Dataset (814,)
# noise_ceilings/subj01/nsdgeneral -> Dataset (12687,)
# noise_ceilings/subj01/parietal -> Dataset (1260,)
# noise_ceilings/subj01/ventral -> Dataset (3027,)
# noise_ceilings/subj01/whole_brain -> Dataset (36776,)
# noise_ceilings/subj02 -> Group
# noise_ceilings/subj02/EBA -> Dataset (1945,)
# noise_ceilings/subj02/FBA-1 -> Dataset (0,)
# noise_ceilings/subj02/FBA-2 -> Dataset (702,)
# noise_ceilings/subj02/FFA-1 -> Dataset (277,)
# noise_ceilings/subj02/FFA-2 -> Dataset (359,)
# noise_ceilings/subj02/OFA -> Dataset (306,)
# noise_ceilings/subj02/OPA -> Dataset (1142,)
# noise_ceilings/subj02/OWFA -> Dataset (362,)
# noise_ceilings/subj02/PPA -> Dataset (639,)
# noise_ceilings/subj02/RSC -> Dataset (672,)
# noise_ceilings/subj02/V1d -> Dataset (489,)
# noise_ceilings/subj02/V1v -> Dataset (442,)
# noise_ceilings/subj02/V2d -> Dataset (369,)
# noise_ceilings/subj02/V2v -> Dataset (439,)
# noise_ceilings/subj02/V3d -> Dataset (438,)
# noise_ceilings/subj02/V3v -> Dataset (423,)
# noise_ceilings/subj02/VWFA-1 -> Dataset (290,)
# noise_ceilings/subj02/VWFA-2 -> Dataset (133,)
# noise_ceilings/subj02/early -> Dataset (3075,)
# noise_ceilings/subj02/hV4 -> Dataset (419,)
# noise_ceilings/subj02/lateral -> Dataset (1787,)
# noise_ceilings/subj02/midlateral -> Dataset (612,)
# noise_ceilings/subj02/midparietal -> Dataset (537,)
# noise_ceilings/subj02/midventral -> Dataset (524,)
# noise_ceilings/subj02/nsdgeneral -> Dataset (10995,)
# noise_ceilings/subj02/parietal -> Dataset (1244,)
# noise_ceilings/subj02/ventral -> Dataset (3195,)
# noise_ceilings/subj02/whole_brain -> Dataset (38407,)
# noise_ceilings/subj03 -> Group
# noise_ceilings/subj03/EBA -> Dataset (2336,)
# noise_ceilings/subj03/FBA-1 -> Dataset (586,)
# noise_ceilings/subj03/FBA-2 -> Dataset (126,)
# noise_ceilings/subj03/FFA-1 -> Dataset (469,)
# noise_ceilings/subj03/FFA-2 -> Dataset (39,)
# noise_ceilings/subj03/OFA -> Dataset (592,)
# noise_ceilings/subj03/OPA -> Dataset (1071,)
# noise_ceilings/subj03/OWFA -> Dataset (434,)
# noise_ceilings/subj03/PPA -> Dataset (791,)
# noise_ceilings/subj03/RSC -> Dataset (333,)
# noise_ceilings/subj03/V1d -> Dataset (481,)
# noise_ceilings/subj03/V1v -> Dataset (618,)
# noise_ceilings/subj03/V2d -> Dataset (424,)
# noise_ceilings/subj03/V2v -> Dataset (566,)
# noise_ceilings/subj03/V3d -> Dataset (424,)
# noise_ceilings/subj03/V3v -> Dataset (372,)
# noise_ceilings/subj03/VWFA-1 -> Dataset (527,)
# noise_ceilings/subj03/VWFA-2 -> Dataset (11,)
# noise_ceilings/subj03/early -> Dataset (3326,)
# noise_ceilings/subj03/hV4 -> Dataset (333,)
# noise_ceilings/subj03/lateral -> Dataset (2300,)
# noise_ceilings/subj03/midlateral -> Dataset (659,)
# noise_ceilings/subj03/midparietal -> Dataset (545,)
# noise_ceilings/subj03/midventral -> Dataset (732,)
# noise_ceilings/subj03/nsdgeneral -> Dataset (11562,)
# noise_ceilings/subj03/parietal -> Dataset (1180,)
# noise_ceilings/subj03/ventral -> Dataset (2800,)
# noise_ceilings/subj03/whole_brain -> Dataset (24715,)
# noise_ceilings/subj04 -> Group
# noise_ceilings/subj04/EBA -> Dataset (2410,)
# noise_ceilings/subj04/FBA-1 -> Dataset (112,)
# noise_ceilings/subj04/FBA-2 -> Dataset (337,)
# noise_ceilings/subj04/FFA-1 -> Dataset (414,)
# noise_ceilings/subj04/FFA-2 -> Dataset (292,)
# noise_ceilings/subj04/OFA -> Dataset (447,)
# noise_ceilings/subj04/OPA -> Dataset (984,)
# noise_ceilings/subj04/OWFA -> Dataset (320,)
# noise_ceilings/subj04/PPA -> Dataset (600,)
# noise_ceilings/subj04/RSC -> Dataset (497,)
# noise_ceilings/subj04/V1d -> Dataset (318,)
# noise_ceilings/subj04/V1v -> Dataset (403,)
# noise_ceilings/subj04/V2d -> Dataset (319,)
# noise_ceilings/subj04/V2v -> Dataset (412,)
# noise_ceilings/subj04/V3d -> Dataset (276,)
# noise_ceilings/subj04/V3v -> Dataset (378,)
# noise_ceilings/subj04/VWFA-1 -> Dataset (425,)
# noise_ceilings/subj04/VWFA-2 -> Dataset (12,)
# noise_ceilings/subj04/early -> Dataset (2794,)
# noise_ceilings/subj04/hV4 -> Dataset (389,)
# noise_ceilings/subj04/lateral -> Dataset (1893,)
# noise_ceilings/subj04/midlateral -> Dataset (517,)
# noise_ceilings/subj04/midparietal -> Dataset (446,)
# noise_ceilings/subj04/midventral -> Dataset (706,)
# noise_ceilings/subj04/nsdgeneral -> Dataset (9945,)
# noise_ceilings/subj04/parietal -> Dataset (916,)
# noise_ceilings/subj04/ventral -> Dataset (2648,)
# noise_ceilings/subj04/whole_brain -> Dataset (25516,)
# noise_ceilings/subj05 -> Group
# noise_ceilings/subj05/EBA -> Dataset (2549,)
# noise_ceilings/subj05/FBA-1 -> Dataset (412,)
# noise_ceilings/subj05/FBA-2 -> Dataset (256,)
# noise_ceilings/subj05/FFA-1 -> Dataset (391,)
# noise_ceilings/subj05/FFA-2 -> Dataset (238,)
# noise_ceilings/subj05/OFA -> Dataset (688,)
# noise_ceilings/subj05/OPA -> Dataset (1084,)
# noise_ceilings/subj05/OWFA -> Dataset (389,)
# noise_ceilings/subj05/PPA -> Dataset (857,)
# noise_ceilings/subj05/RSC -> Dataset (480,)
# noise_ceilings/subj05/V1d -> Dataset (540,)
# noise_ceilings/subj05/V1v -> Dataset (386,)
# noise_ceilings/subj05/V2d -> Dataset (463,)
# noise_ceilings/subj05/V2v -> Dataset (478,)
# noise_ceilings/subj05/V3d -> Dataset (389,)
# noise_ceilings/subj05/V3v -> Dataset (398,)
# noise_ceilings/subj05/VWFA-1 -> Dataset (336,)
# noise_ceilings/subj05/VWFA-2 -> Dataset (171,)
# noise_ceilings/subj05/early -> Dataset (3487,)
# noise_ceilings/subj05/hV4 -> Dataset (472,)
# noise_ceilings/subj05/lateral -> Dataset (1874,)
# noise_ceilings/subj05/midlateral -> Dataset (543,)
# noise_ceilings/subj05/midparietal -> Dataset (496,)
# noise_ceilings/subj05/midventral -> Dataset (925,)
# noise_ceilings/subj05/nsdgeneral -> Dataset (11120,)
# noise_ceilings/subj05/parietal -> Dataset (1020,)
# noise_ceilings/subj05/ventral -> Dataset (2737,)
# noise_ceilings/subj05/whole_brain -> Dataset (31764,)
# noise_ceilings/subj06 -> Group
# noise_ceilings/subj06/EBA -> Dataset (3282,)
# noise_ceilings/subj06/FBA-1 -> Dataset (905,)
# noise_ceilings/subj06/FBA-2 -> Dataset (225,)
# noise_ceilings/subj06/FFA-1 -> Dataset (290,)
# noise_ceilings/subj06/FFA-2 -> Dataset (337,)
# noise_ceilings/subj06/OFA -> Dataset (473,)
# noise_ceilings/subj06/OPA -> Dataset (1169,)
# noise_ceilings/subj06/OWFA -> Dataset (482,)
# noise_ceilings/subj06/PPA -> Dataset (904,)
# noise_ceilings/subj06/RSC -> Dataset (502,)
# noise_ceilings/subj06/V1d -> Dataset (692,)
# noise_ceilings/subj06/V1v -> Dataset (365,)
# noise_ceilings/subj06/V2d -> Dataset (536,)
# noise_ceilings/subj06/V2v -> Dataset (512,)
# noise_ceilings/subj06/V3d -> Dataset (589,)
# noise_ceilings/subj06/V3v -> Dataset (471,)
# noise_ceilings/subj06/VWFA-1 -> Dataset (561,)
# noise_ceilings/subj06/VWFA-2 -> Dataset (316,)
# noise_ceilings/subj06/early -> Dataset (4646,)
# noise_ceilings/subj06/hV4 -> Dataset (400,)
# noise_ceilings/subj06/lateral -> Dataset (2398,)
# noise_ceilings/subj06/midlateral -> Dataset (1021,)
# noise_ceilings/subj06/midparietal -> Dataset (726,)
# noise_ceilings/subj06/midventral -> Dataset (1089,)
# noise_ceilings/subj06/nsdgeneral -> Dataset (15199,)
# noise_ceilings/subj06/parietal -> Dataset (1341,)
# noise_ceilings/subj06/ventral -> Dataset (3923,)
# noise_ceilings/subj06/whole_brain -> Dataset (40468,)
# noise_ceilings/subj07 -> Group
# noise_ceilings/subj07/EBA -> Dataset (1886,)
# noise_ceilings/subj07/FBA-1 -> Dataset (0,)
# noise_ceilings/subj07/FBA-2 -> Dataset (230,)
# noise_ceilings/subj07/FFA-1 -> Dataset (240,)
# noise_ceilings/subj07/FFA-2 -> Dataset (5,)
# noise_ceilings/subj07/OFA -> Dataset (234,)
# noise_ceilings/subj07/OPA -> Dataset (941,)
# noise_ceilings/subj07/OWFA -> Dataset (473,)
# noise_ceilings/subj07/PPA -> Dataset (480,)
# noise_ceilings/subj07/RSC -> Dataset (355,)
# noise_ceilings/subj07/V1d -> Dataset (514,)
# noise_ceilings/subj07/V1v -> Dataset (429,)
# noise_ceilings/subj07/V2d -> Dataset (346,)
# noise_ceilings/subj07/V2v -> Dataset (451,)
# noise_ceilings/subj07/V3d -> Dataset (279,)
# noise_ceilings/subj07/V3v -> Dataset (283,)
# noise_ceilings/subj07/VWFA-1 -> Dataset (265,)
# noise_ceilings/subj07/VWFA-2 -> Dataset (446,)
# noise_ceilings/subj07/early -> Dataset (2825,)
# noise_ceilings/subj07/hV4 -> Dataset (281,)
# noise_ceilings/subj07/lateral -> Dataset (1816,)
# noise_ceilings/subj07/midlateral -> Dataset (513,)
# noise_ceilings/subj07/midparietal -> Dataset (344,)
# noise_ceilings/subj07/midventral -> Dataset (578,)
# noise_ceilings/subj07/nsdgeneral -> Dataset (9118,)
# noise_ceilings/subj07/parietal -> Dataset (882,)
# noise_ceilings/subj07/ventral -> Dataset (2146,)
# noise_ceilings/subj07/whole_brain -> Dataset (20513,)
# noise_ceilings/subj08 -> Group
# noise_ceilings/subj08/EBA -> Dataset (1762,)
# noise_ceilings/subj08/FBA-1 -> Dataset (303,)
# noise_ceilings/subj08/FBA-2 -> Dataset (307,)
# noise_ceilings/subj08/FFA-1 -> Dataset (432,)
# noise_ceilings/subj08/FFA-2 -> Dataset (389,)
# noise_ceilings/subj08/OFA -> Dataset (199,)
# noise_ceilings/subj08/OPA -> Dataset (934,)
# noise_ceilings/subj08/OWFA -> Dataset (414,)
# noise_ceilings/subj08/PPA -> Dataset (571,)
# noise_ceilings/subj08/RSC -> Dataset (260,)
# noise_ceilings/subj08/V1d -> Dataset (410,)
# noise_ceilings/subj08/V1v -> Dataset (372,)
# noise_ceilings/subj08/V2d -> Dataset (329,)
# noise_ceilings/subj08/V2v -> Dataset (401,)
# noise_ceilings/subj08/V3d -> Dataset (285,)
# noise_ceilings/subj08/V3v -> Dataset (331,)
# noise_ceilings/subj08/VWFA-1 -> Dataset (552,)
# noise_ceilings/subj08/VWFA-2 -> Dataset (20,)
# noise_ceilings/subj08/early -> Dataset (2431,)
# noise_ceilings/subj08/hV4 -> Dataset (340,)
# noise_ceilings/subj08/lateral -> Dataset (1508,)
# noise_ceilings/subj08/midlateral -> Dataset (425,)
# noise_ceilings/subj08/midparietal -> Dataset (302,)
# noise_ceilings/subj08/midventral -> Dataset (570,)
# noise_ceilings/subj08/nsdgeneral -> Dataset (8424,)
# noise_ceilings/subj08/parietal -> Dataset (775,)
# noise_ceilings/subj08/ventral -> Dataset (2404,)
# noise_ceilings/subj08/whole_brain -> Dataset (13610,)
# roi_labels -> Group
# roi_labels/subj01 -> Group
# roi_labels/subj01/EBA -> Dataset (81, 104, 83)
# roi_labels/subj01/FBA-1 -> Dataset (81, 104, 83)
# roi_labels/subj01/FBA-2 -> Dataset (81, 104, 83)
# roi_labels/subj01/FFA-1 -> Dataset (81, 104, 83)
# roi_labels/subj01/FFA-2 -> Dataset (81, 104, 83)
# roi_labels/subj01/OFA -> Dataset (81, 104, 83)
# roi_labels/subj01/OPA -> Dataset (81, 104, 83)
# roi_labels/subj01/OWFA -> Dataset (81, 104, 83)
# roi_labels/subj01/PPA -> Dataset (81, 104, 83)
# roi_labels/subj01/RSC -> Dataset (81, 104, 83)
# roi_labels/subj01/V1d -> Dataset (81, 104, 83)
# roi_labels/subj01/V1v -> Dataset (81, 104, 83)
# roi_labels/subj01/V2d -> Dataset (81, 104, 83)
# roi_labels/subj01/V2v -> Dataset (81, 104, 83)
# roi_labels/subj01/V3d -> Dataset (81, 104, 83)
# roi_labels/subj01/V3v -> Dataset (81, 104, 83)
# roi_labels/subj01/VWFA-1 -> Dataset (81, 104, 83)
# roi_labels/subj01/VWFA-2 -> Dataset (81, 104, 83)
# roi_labels/subj01/early -> Dataset (81, 104, 83)
# roi_labels/subj01/hV4 -> Dataset (81, 104, 83)
# roi_labels/subj01/lateral -> Dataset (81, 104, 83)
# roi_labels/subj01/midlateral -> Dataset (81, 104, 83)
# roi_labels/subj01/midparietal -> Dataset (81, 104, 83)
# roi_labels/subj01/midventral -> Dataset (81, 104, 83)
# roi_labels/subj01/nsdgeneral -> Dataset (81, 104, 83)
# roi_labels/subj01/parietal -> Dataset (81, 104, 83)
# roi_labels/subj01/ventral -> Dataset (81, 104, 83)
# roi_labels/subj01/whole_brain -> Dataset (81, 104, 83)
# roi_labels/subj02 -> Group
# roi_labels/subj02/EBA -> Dataset (82, 106, 84)
# roi_labels/subj02/FBA-1 -> Dataset (82, 106, 84)
# roi_labels/subj02/FBA-2 -> Dataset (82, 106, 84)
# roi_labels/subj02/FFA-1 -> Dataset (82, 106, 84)
# roi_labels/subj02/FFA-2 -> Dataset (82, 106, 84)
# roi_labels/subj02/OFA -> Dataset (82, 106, 84)
# roi_labels/subj02/OPA -> Dataset (82, 106, 84)
# roi_labels/subj02/OWFA -> Dataset (82, 106, 84)
# roi_labels/subj02/PPA -> Dataset (82, 106, 84)
# roi_labels/subj02/RSC -> Dataset (82, 106, 84)
# roi_labels/subj02/V1d -> Dataset (82, 106, 84)
# roi_labels/subj02/V1v -> Dataset (82, 106, 84)
# roi_labels/subj02/V2d -> Dataset (82, 106, 84)
# roi_labels/subj02/V2v -> Dataset (82, 106, 84)
# roi_labels/subj02/V3d -> Dataset (82, 106, 84)
# roi_labels/subj02/V3v -> Dataset (82, 106, 84)
# roi_labels/subj02/VWFA-1 -> Dataset (82, 106, 84)
# roi_labels/subj02/VWFA-2 -> Dataset (82, 106, 84)
# roi_labels/subj02/early -> Dataset (82, 106, 84)
# roi_labels/subj02/hV4 -> Dataset (82, 106, 84)
# roi_labels/subj02/lateral -> Dataset (82, 106, 84)
# roi_labels/subj02/midlateral -> Dataset (82, 106, 84)
# roi_labels/subj02/midparietal -> Dataset (82, 106, 84)
# roi_labels/subj02/midventral -> Dataset (82, 106, 84)
# roi_labels/subj02/nsdgeneral -> Dataset (82, 106, 84)
# roi_labels/subj02/parietal -> Dataset (82, 106, 84)
# roi_labels/subj02/ventral -> Dataset (82, 106, 84)
# roi_labels/subj02/whole_brain -> Dataset (82, 106, 84)
# roi_labels/subj03 -> Group
# roi_labels/subj03/EBA -> Dataset (81, 106, 82)
# roi_labels/subj03/FBA-1 -> Dataset (81, 106, 82)
# roi_labels/subj03/FBA-2 -> Dataset (81, 106, 82)
# roi_labels/subj03/FFA-1 -> Dataset (81, 106, 82)
# roi_labels/subj03/FFA-2 -> Dataset (81, 106, 82)
# roi_labels/subj03/OFA -> Dataset (81, 106, 82)
# roi_labels/subj03/OPA -> Dataset (81, 106, 82)
# roi_labels/subj03/OWFA -> Dataset (81, 106, 82)
# roi_labels/subj03/PPA -> Dataset (81, 106, 82)
# roi_labels/subj03/RSC -> Dataset (81, 106, 82)
# roi_labels/subj03/V1d -> Dataset (81, 106, 82)
# roi_labels/subj03/V1v -> Dataset (81, 106, 82)
# roi_labels/subj03/V2d -> Dataset (81, 106, 82)
# roi_labels/subj03/V2v -> Dataset (81, 106, 82)
# roi_labels/subj03/V3d -> Dataset (81, 106, 82)
# roi_labels/subj03/V3v -> Dataset (81, 106, 82)
# roi_labels/subj03/VWFA-1 -> Dataset (81, 106, 82)
# roi_labels/subj03/VWFA-2 -> Dataset (81, 106, 82)
# roi_labels/subj03/early -> Dataset (81, 106, 82)
# roi_labels/subj03/hV4 -> Dataset (81, 106, 82)
# roi_labels/subj03/lateral -> Dataset (81, 106, 82)
# roi_labels/subj03/midlateral -> Dataset (81, 106, 82)
# roi_labels/subj03/midparietal -> Dataset (81, 106, 82)
# roi_labels/subj03/midventral -> Dataset (81, 106, 82)
# roi_labels/subj03/nsdgeneral -> Dataset (81, 106, 82)
# roi_labels/subj03/parietal -> Dataset (81, 106, 82)
# roi_labels/subj03/ventral -> Dataset (81, 106, 82)
# roi_labels/subj03/whole_brain -> Dataset (81, 106, 82)
# roi_labels/subj04 -> Group
# roi_labels/subj04/EBA -> Dataset (85, 99, 80)
# roi_labels/subj04/FBA-1 -> Dataset (85, 99, 80)
# roi_labels/subj04/FBA-2 -> Dataset (85, 99, 80)
# roi_labels/subj04/FFA-1 -> Dataset (85, 99, 80)
# roi_labels/subj04/FFA-2 -> Dataset (85, 99, 80)
# roi_labels/subj04/OFA -> Dataset (85, 99, 80)
# roi_labels/subj04/OPA -> Dataset (85, 99, 80)
# roi_labels/subj04/OWFA -> Dataset (85, 99, 80)
# roi_labels/subj04/PPA -> Dataset (85, 99, 80)
# roi_labels/subj04/RSC -> Dataset (85, 99, 80)
# roi_labels/subj04/V1d -> Dataset (85, 99, 80)
# roi_labels/subj04/V1v -> Dataset (85, 99, 80)
# roi_labels/subj04/V2d -> Dataset (85, 99, 80)
# roi_labels/subj04/V2v -> Dataset (85, 99, 80)
# roi_labels/subj04/V3d -> Dataset (85, 99, 80)
# roi_labels/subj04/V3v -> Dataset (85, 99, 80)
# roi_labels/subj04/VWFA-1 -> Dataset (85, 99, 80)
# roi_labels/subj04/VWFA-2 -> Dataset (85, 99, 80)
# roi_labels/subj04/early -> Dataset (85, 99, 80)
# roi_labels/subj04/hV4 -> Dataset (85, 99, 80)
# roi_labels/subj04/lateral -> Dataset (85, 99, 80)
# roi_labels/subj04/midlateral -> Dataset (85, 99, 80)
# roi_labels/subj04/midparietal -> Dataset (85, 99, 80)
# roi_labels/subj04/midventral -> Dataset (85, 99, 80)
# roi_labels/subj04/nsdgeneral -> Dataset (85, 99, 80)
# roi_labels/subj04/parietal -> Dataset (85, 99, 80)
# roi_labels/subj04/ventral -> Dataset (85, 99, 80)
# roi_labels/subj04/whole_brain -> Dataset (85, 99, 80)
# roi_labels/subj05 -> Group
# roi_labels/subj05/EBA -> Dataset (79, 97, 78)
# roi_labels/subj05/FBA-1 -> Dataset (79, 97, 78)
# roi_labels/subj05/FBA-2 -> Dataset (79, 97, 78)
# roi_labels/subj05/FFA-1 -> Dataset (79, 97, 78)
# roi_labels/subj05/FFA-2 -> Dataset (79, 97, 78)
# roi_labels/subj05/OFA -> Dataset (79, 97, 78)
# roi_labels/subj05/OPA -> Dataset (79, 97, 78)
# roi_labels/subj05/OWFA -> Dataset (79, 97, 78)
# roi_labels/subj05/PPA -> Dataset (79, 97, 78)
# roi_labels/subj05/RSC -> Dataset (79, 97, 78)
# roi_labels/subj05/V1d -> Dataset (79, 97, 78)
# roi_labels/subj05/V1v -> Dataset (79, 97, 78)
# roi_labels/subj05/V2d -> Dataset (79, 97, 78)
# roi_labels/subj05/V2v -> Dataset (79, 97, 78)
# roi_labels/subj05/V3d -> Dataset (79, 97, 78)
# roi_labels/subj05/V3v -> Dataset (79, 97, 78)
# roi_labels/subj05/VWFA-1 -> Dataset (79, 97, 78)
# roi_labels/subj05/VWFA-2 -> Dataset (79, 97, 78)
# roi_labels/subj05/early -> Dataset (79, 97, 78)
# roi_labels/subj05/hV4 -> Dataset (79, 97, 78)
# roi_labels/subj05/lateral -> Dataset (79, 97, 78)
# roi_labels/subj05/midlateral -> Dataset (79, 97, 78)
# roi_labels/subj05/midparietal -> Dataset (79, 97, 78)
# roi_labels/subj05/midventral -> Dataset (79, 97, 78)
# roi_labels/subj05/nsdgeneral -> Dataset (79, 97, 78)
# roi_labels/subj05/parietal -> Dataset (79, 97, 78)
# roi_labels/subj05/ventral -> Dataset (79, 97, 78)
# roi_labels/subj05/whole_brain -> Dataset (79, 97, 78)
# roi_labels/subj06 -> Group
# roi_labels/subj06/EBA -> Dataset (85, 113, 83)
# roi_labels/subj06/FBA-1 -> Dataset (85, 113, 83)
# roi_labels/subj06/FBA-2 -> Dataset (85, 113, 83)
# roi_labels/subj06/FFA-1 -> Dataset (85, 113, 83)
# roi_labels/subj06/FFA-2 -> Dataset (85, 113, 83)
# roi_labels/subj06/OFA -> Dataset (85, 113, 83)
# roi_labels/subj06/OPA -> Dataset (85, 113, 83)
# roi_labels/subj06/OWFA -> Dataset (85, 113, 83)
# roi_labels/subj06/PPA -> Dataset (85, 113, 83)
# roi_labels/subj06/RSC -> Dataset (85, 113, 83)
# roi_labels/subj06/V1d -> Dataset (85, 113, 83)
# roi_labels/subj06/V1v -> Dataset (85, 113, 83)
# roi_labels/subj06/V2d -> Dataset (85, 113, 83)
# roi_labels/subj06/V2v -> Dataset (85, 113, 83)
# roi_labels/subj06/V3d -> Dataset (85, 113, 83)
# roi_labels/subj06/V3v -> Dataset (85, 113, 83)
# roi_labels/subj06/VWFA-1 -> Dataset (85, 113, 83)
# roi_labels/subj06/VWFA-2 -> Dataset (85, 113, 83)
# roi_labels/subj06/early -> Dataset (85, 113, 83)
# roi_labels/subj06/hV4 -> Dataset (85, 113, 83)
# roi_labels/subj06/lateral -> Dataset (85, 113, 83)
# roi_labels/subj06/midlateral -> Dataset (85, 113, 83)
# roi_labels/subj06/midparietal -> Dataset (85, 113, 83)
# roi_labels/subj06/midventral -> Dataset (85, 113, 83)
# roi_labels/subj06/nsdgeneral -> Dataset (85, 113, 83)
# roi_labels/subj06/parietal -> Dataset (85, 113, 83)
# roi_labels/subj06/ventral -> Dataset (85, 113, 83)
# roi_labels/subj06/whole_brain -> Dataset (85, 113, 83)
# roi_labels/subj07 -> Group
# roi_labels/subj07/EBA -> Dataset (78, 95, 81)
# roi_labels/subj07/FBA-1 -> Dataset (78, 95, 81)
# roi_labels/subj07/FBA-2 -> Dataset (78, 95, 81)
# roi_labels/subj07/FFA-1 -> Dataset (78, 95, 81)
# roi_labels/subj07/FFA-2 -> Dataset (78, 95, 81)
# roi_labels/subj07/OFA -> Dataset (78, 95, 81)
# roi_labels/subj07/OPA -> Dataset (78, 95, 81)
# roi_labels/subj07/OWFA -> Dataset (78, 95, 81)
# roi_labels/subj07/PPA -> Dataset (78, 95, 81)
# roi_labels/subj07/RSC -> Dataset (78, 95, 81)
# roi_labels/subj07/V1d -> Dataset (78, 95, 81)
# roi_labels/subj07/V1v -> Dataset (78, 95, 81)
# roi_labels/subj07/V2d -> Dataset (78, 95, 81)
# roi_labels/subj07/V2v -> Dataset (78, 95, 81)
# roi_labels/subj07/V3d -> Dataset (78, 95, 81)
# roi_labels/subj07/V3v -> Dataset (78, 95, 81)
# roi_labels/subj07/VWFA-1 -> Dataset (78, 95, 81)
# roi_labels/subj07/VWFA-2 -> Dataset (78, 95, 81)
# roi_labels/subj07/early -> Dataset (78, 95, 81)
# roi_labels/subj07/hV4 -> Dataset (78, 95, 81)
# roi_labels/subj07/lateral -> Dataset (78, 95, 81)
# roi_labels/subj07/midlateral -> Dataset (78, 95, 81)
# roi_labels/subj07/midparietal -> Dataset (78, 95, 81)
# roi_labels/subj07/midventral -> Dataset (78, 95, 81)
# roi_labels/subj07/nsdgeneral -> Dataset (78, 95, 81)
# roi_labels/subj07/parietal -> Dataset (78, 95, 81)
# roi_labels/subj07/ventral -> Dataset (78, 95, 81)
# roi_labels/subj07/whole_brain -> Dataset (78, 95, 81)
# roi_labels/subj08 -> Group
# roi_labels/subj08/EBA -> Dataset (80, 103, 78)
# roi_labels/subj08/FBA-1 -> Dataset (80, 103, 78)
# roi_labels/subj08/FBA-2 -> Dataset (80, 103, 78)
# roi_labels/subj08/FFA-1 -> Dataset (80, 103, 78)
# roi_labels/subj08/FFA-2 -> Dataset (80, 103, 78)
# roi_labels/subj08/OFA -> Dataset (80, 103, 78)
# roi_labels/subj08/OPA -> Dataset (80, 103, 78)
# roi_labels/subj08/OWFA -> Dataset (80, 103, 78)
# roi_labels/subj08/PPA -> Dataset (80, 103, 78)
# roi_labels/subj08/RSC -> Dataset (80, 103, 78)
# roi_labels/subj08/V1d -> Dataset (80, 103, 78)
# roi_labels/subj08/V1v -> Dataset (80, 103, 78)
# roi_labels/subj08/V2d -> Dataset (80, 103, 78)
# roi_labels/subj08/V2v -> Dataset (80, 103, 78)
# roi_labels/subj08/V3d -> Dataset (80, 103, 78)
# roi_labels/subj08/V3v -> Dataset (80, 103, 78)
# roi_labels/subj08/VWFA-1 -> Dataset (80, 103, 78)
# roi_labels/subj08/VWFA-2 -> Dataset (80, 103, 78)
# roi_labels/subj08/early -> Dataset (80, 103, 78)
# roi_labels/subj08/hV4 -> Dataset (80, 103, 78)
# roi_labels/subj08/lateral -> Dataset (80, 103, 78)
# roi_labels/subj08/midlateral -> Dataset (80, 103, 78)
# roi_labels/subj08/midparietal -> Dataset (80, 103, 78)
# roi_labels/subj08/midventral -> Dataset (80, 103, 78)
# roi_labels/subj08/nsdgeneral -> Dataset (80, 103, 78)
# roi_labels/subj08/parietal -> Dataset (80, 103, 78)
# roi_labels/subj08/ventral -> Dataset (80, 103, 78)
# roi_labels/subj08/whole_brain -> Dataset (80, 103, 78)
# roi_labels_nc -> Group
# roi_labels_nc/subj01 -> Group
# roi_labels_nc/subj01/EBA -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/FBA-1 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/FBA-2 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/FFA-1 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/FFA-2 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/OFA -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/OPA -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/OWFA -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/PPA -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/RSC -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/V1d -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/V1v -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/V2d -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/V2v -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/V3d -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/V3v -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/VWFA-1 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/VWFA-2 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/early -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/hV4 -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/lateral -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/midlateral -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/midparietal -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/midventral -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/nsdgeneral -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/parietal -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/ventral -> Dataset (81, 104, 83)
# roi_labels_nc/subj01/whole_brain -> Dataset (81, 104, 83)
# roi_labels_nc/subj02 -> Group
# roi_labels_nc/subj02/EBA -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/FBA-1 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/FBA-2 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/FFA-1 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/FFA-2 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/OFA -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/OPA -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/OWFA -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/PPA -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/RSC -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/V1d -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/V1v -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/V2d -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/V2v -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/V3d -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/V3v -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/VWFA-1 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/VWFA-2 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/early -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/hV4 -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/lateral -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/midlateral -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/midparietal -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/midventral -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/nsdgeneral -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/parietal -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/ventral -> Dataset (82, 106, 84)
# roi_labels_nc/subj02/whole_brain -> Dataset (82, 106, 84)
# roi_labels_nc/subj03 -> Group
# roi_labels_nc/subj03/EBA -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/FBA-1 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/FBA-2 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/FFA-1 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/FFA-2 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/OFA -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/OPA -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/OWFA -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/PPA -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/RSC -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/V1d -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/V1v -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/V2d -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/V2v -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/V3d -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/V3v -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/VWFA-1 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/VWFA-2 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/early -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/hV4 -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/lateral -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/midlateral -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/midparietal -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/midventral -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/nsdgeneral -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/parietal -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/ventral -> Dataset (81, 106, 82)
# roi_labels_nc/subj03/whole_brain -> Dataset (81, 106, 82)
# roi_labels_nc/subj04 -> Group
# roi_labels_nc/subj04/EBA -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/FBA-1 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/FBA-2 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/FFA-1 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/FFA-2 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/OFA -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/OPA -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/OWFA -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/PPA -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/RSC -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/V1d -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/V1v -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/V2d -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/V2v -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/V3d -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/V3v -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/VWFA-1 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/VWFA-2 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/early -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/hV4 -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/lateral -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/midlateral -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/midparietal -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/midventral -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/nsdgeneral -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/parietal -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/ventral -> Dataset (85, 99, 80)
# roi_labels_nc/subj04/whole_brain -> Dataset (85, 99, 80)
# roi_labels_nc/subj05 -> Group
# roi_labels_nc/subj05/EBA -> Dataset (79, 97, 78)
# roi_labels_nc/subj05/FBA-1 -> Dataset (79, 97, 78)
# roi_labels_nc/subj05/FBA-2 -> Dataset (79, 97, 78)
# roi_labels_nc/subj05/FFA-1 -> Dataset (79, 97, 78)
# roi_labels_nc/subj05/FFA-2 -> Dataset (79, 97, 78)
# roi_labels_nc/subj05/OFA -> Dataset (79, 97, 78)
# roi_labels_nc/subj05/OPA -> Dataset (79, 97, 78)
# ...
# test/neural_data/subj07/OWFA -> Dataset (1000, 473)
# test/neural_data/subj07/PPA -> Dataset (1000, 480)
# test/neural_data/subj07/RSC -> Dataset (1000, 355)
# test/neural_data/subj07/V1d -> Dataset (1000, 514)
# test/neural_data/subj07/V1v -> Dataset (1000, 429)
# test/neural_data/subj07/V2d -> Dataset (1000, 346)
# test/neural_data/subj07/V2v -> Dataset (1000, 451)
# test/neural_data/subj07/V3d -> Dataset (1000, 279)
# test/neural_data/subj07/V3v -> Dataset (1000, 283)
# test/neural_data/subj07/VWFA-1 -> Dataset (1000, 265)
# test/neural_data/subj07/VWFA-2 -> Dataset (1000, 446)
# test/neural_data/subj07/early -> Dataset (1000, 2825)
# test/neural_data/subj07/hV4 -> Dataset (1000, 281)
# test/neural_data/subj07/lateral -> Dataset (1000, 1816)
# test/neural_data/subj07/midlateral -> Dataset (1000, 513)
# test/neural_data/subj07/midparietal -> Dataset (1000, 344)
# test/neural_data/subj07/midventral -> Dataset (1000, 578)
# test/neural_data/subj07/nsdgeneral -> Dataset (1000, 9118)
# test/neural_data/subj07/parietal -> Dataset (1000, 882)
# test/neural_data/subj07/ventral -> Dataset (1000, 2146)
# test/neural_data/subj07/whole_brain -> Dataset (1000, 20513)
# test/neural_data/subj08 -> Group
# test/neural_data/subj08/EBA -> Dataset (907, 1762)
# test/neural_data/subj08/FBA-1 -> Dataset (907, 303)
# test/neural_data/subj08/FBA-2 -> Dataset (907, 307)
# test/neural_data/subj08/FFA-1 -> Dataset (907, 432)
# test/neural_data/subj08/FFA-2 -> Dataset (907, 389)
# test/neural_data/subj08/OFA -> Dataset (907, 199)
# test/neural_data/subj08/OPA -> Dataset (907, 934)
# test/neural_data/subj08/OWFA -> Dataset (907, 414)
# test/neural_data/subj08/PPA -> Dataset (907, 571)
# test/neural_data/subj08/RSC -> Dataset (907, 260)
# test/neural_data/subj08/V1d -> Dataset (907, 410)
# test/neural_data/subj08/V1v -> Dataset (907, 372)
# test/neural_data/subj08/V2d -> Dataset (907, 329)
# test/neural_data/subj08/V2v -> Dataset (907, 401)
# test/neural_data/subj08/V3d -> Dataset (907, 285)
# test/neural_data/subj08/V3v -> Dataset (907, 331)
# test/neural_data/subj08/VWFA-1 -> Dataset (907, 552)
# test/neural_data/subj08/VWFA-2 -> Dataset (907, 20)
# test/neural_data/subj08/early -> Dataset (907, 2431)
# test/neural_data/subj08/hV4 -> Dataset (907, 340)
# test/neural_data/subj08/lateral -> Dataset (907, 1508)
# test/neural_data/subj08/midlateral -> Dataset (907, 425)
# test/neural_data/subj08/midparietal -> Dataset (907, 302)
# test/neural_data/subj08/midventral -> Dataset (907, 570)
# test/neural_data/subj08/nsdgeneral -> Dataset (907, 8424)
# test/neural_data/subj08/parietal -> Dataset (907, 775)
# test/neural_data/subj08/ventral -> Dataset (907, 2404)
# test/neural_data/subj08/whole_brain -> Dataset (907, 13610)
# test/stimulus_ids -> Group
# test/stimulus_ids/subj01 -> Dataset (1000,)
# test/stimulus_ids/subj02 -> Dataset (1000,)
# test/stimulus_ids/subj03 -> Dataset (930,)
# test/stimulus_ids/subj04 -> Dataset (907,)
# test/stimulus_ids/subj05 -> Dataset (1000,)
# test/stimulus_ids/subj06 -> Dataset (930,)
# test/stimulus_ids/subj07 -> Dataset (1000,)
# test/stimulus_ids/subj08 -> Dataset (907,)
# train -> Group
# train/neural_data -> Group
# train/neural_data/subj01 -> Group
# train/neural_data/subj01/EBA -> Dataset (9000, 2078)
# train/neural_data/subj01/FBA-1 -> Dataset (9000, 339)
# train/neural_data/subj01/FBA-2 -> Dataset (9000, 255)
# train/neural_data/subj01/FFA-1 -> Dataset (9000, 423)
# train/neural_data/subj01/FFA-2 -> Dataset (9000, 173)
# train/neural_data/subj01/OFA -> Dataset (9000, 283)
# train/neural_data/subj01/OPA -> Dataset (9000, 1353)
# train/neural_data/subj01/OWFA -> Dataset (9000, 369)
# train/neural_data/subj01/PPA -> Dataset (9000, 604)
# train/neural_data/subj01/RSC -> Dataset (9000, 362)
# train/neural_data/subj01/V1d -> Dataset (9000, 727)
# train/neural_data/subj01/V1v -> Dataset (9000, 570)
# train/neural_data/subj01/V2d -> Dataset (9000, 557)
# train/neural_data/subj01/V2v -> Dataset (9000, 725)
# train/neural_data/subj01/V3d -> Dataset (9000, 505)
# train/neural_data/subj01/V3v -> Dataset (9000, 554)
# train/neural_data/subj01/VWFA-1 -> Dataset (9000, 666)
# train/neural_data/subj01/VWFA-2 -> Dataset (9000, 281)
# train/neural_data/subj01/early -> Dataset (9000, 3952)
# train/neural_data/subj01/hV4 -> Dataset (9000, 578)
# train/neural_data/subj01/lateral -> Dataset (9000, 2161)
# train/neural_data/subj01/midlateral -> Dataset (9000, 735)
# train/neural_data/subj01/midparietal -> Dataset (9000, 692)
# train/neural_data/subj01/midventral -> Dataset (9000, 814)
# train/neural_data/subj01/nsdgeneral -> Dataset (9000, 12687)
# train/neural_data/subj01/parietal -> Dataset (9000, 1260)
# train/neural_data/subj01/ventral -> Dataset (9000, 3027)
# train/neural_data/subj01/whole_brain -> Dataset (9000, 36776)
# train/neural_data/subj02 -> Group
# train/neural_data/subj02/EBA -> Dataset (9000, 1945)
# train/neural_data/subj02/FBA-1 -> Dataset (9000, 0)
# train/neural_data/subj02/FBA-2 -> Dataset (9000, 702)
# train/neural_data/subj02/FFA-1 -> Dataset (9000, 277)
# train/neural_data/subj02/FFA-2 -> Dataset (9000, 359)
# train/neural_data/subj02/OFA -> Dataset (9000, 306)
# train/neural_data/subj02/OPA -> Dataset (9000, 1142)
# train/neural_data/subj02/OWFA -> Dataset (9000, 362)
# train/neural_data/subj02/PPA -> Dataset (9000, 639)
# train/neural_data/subj02/RSC -> Dataset (9000, 672)
# train/neural_data/subj02/V1d -> Dataset (9000, 489)
# train/neural_data/subj02/V1v -> Dataset (9000, 442)
# train/neural_data/subj02/V2d -> Dataset (9000, 369)
# train/neural_data/subj02/V2v -> Dataset (9000, 439)
# train/neural_data/subj02/V3d -> Dataset (9000, 438)
# train/neural_data/subj02/V3v -> Dataset (9000, 423)
# train/neural_data/subj02/VWFA-1 -> Dataset (9000, 290)
# train/neural_data/subj02/VWFA-2 -> Dataset (9000, 133)
# train/neural_data/subj02/early -> Dataset (9000, 3075)
# train/neural_data/subj02/hV4 -> Dataset (9000, 419)
# train/neural_data/subj02/lateral -> Dataset (9000, 1787)
# train/neural_data/subj02/midlateral -> Dataset (9000, 612)
# train/neural_data/subj02/midparietal -> Dataset (9000, 537)
# train/neural_data/subj02/midventral -> Dataset (9000, 524)
# train/neural_data/subj02/nsdgeneral -> Dataset (9000, 10995)
# train/neural_data/subj02/parietal -> Dataset (9000, 1244)
# train/neural_data/subj02/ventral -> Dataset (9000, 3195)
# train/neural_data/subj02/whole_brain -> Dataset (9000, 38407)
# train/neural_data/subj03 -> Group
# train/neural_data/subj03/EBA -> Dataset (8481, 2336)
# train/neural_data/subj03/FBA-1 -> Dataset (8481, 586)
# train/neural_data/subj03/FBA-2 -> Dataset (8481, 126)
# train/neural_data/subj03/FFA-1 -> Dataset (8481, 469)
# train/neural_data/subj03/FFA-2 -> Dataset (8481, 39)
# train/neural_data/subj03/OFA -> Dataset (8481, 592)
# train/neural_data/subj03/OPA -> Dataset (8481, 1071)
# train/neural_data/subj03/OWFA -> Dataset (8481, 434)
# train/neural_data/subj03/PPA -> Dataset (8481, 791)
# train/neural_data/subj03/RSC -> Dataset (8481, 333)
# train/neural_data/subj03/V1d -> Dataset (8481, 481)
# train/neural_data/subj03/V1v -> Dataset (8481, 618)
# train/neural_data/subj03/V2d -> Dataset (8481, 424)
# train/neural_data/subj03/V2v -> Dataset (8481, 566)
# train/neural_data/subj03/V3d -> Dataset (8481, 424)
# train/neural_data/subj03/V3v -> Dataset (8481, 372)
# train/neural_data/subj03/VWFA-1 -> Dataset (8481, 527)
# train/neural_data/subj03/VWFA-2 -> Dataset (8481, 11)
# train/neural_data/subj03/early -> Dataset (8481, 3326)
# train/neural_data/subj03/hV4 -> Dataset (8481, 333)
# train/neural_data/subj03/lateral -> Dataset (8481, 2300)
# train/neural_data/subj03/midlateral -> Dataset (8481, 659)
# train/neural_data/subj03/midparietal -> Dataset (8481, 545)
# train/neural_data/subj03/midventral -> Dataset (8481, 732)
# train/neural_data/subj03/nsdgeneral -> Dataset (8481, 11562)
# train/neural_data/subj03/parietal -> Dataset (8481, 1180)
# train/neural_data/subj03/ventral -> Dataset (8481, 2800)
# train/neural_data/subj03/whole_brain -> Dataset (8481, 24715)
# train/neural_data/subj04 -> Group
# train/neural_data/subj04/EBA -> Dataset (8302, 2410)
# train/neural_data/subj04/FBA-1 -> Dataset (8302, 112)
# train/neural_data/subj04/FBA-2 -> Dataset (8302, 337)
# train/neural_data/subj04/FFA-1 -> Dataset (8302, 414)
# train/neural_data/subj04/FFA-2 -> Dataset (8302, 292)
# train/neural_data/subj04/OFA -> Dataset (8302, 447)
# train/neural_data/subj04/OPA -> Dataset (8302, 984)
# train/neural_data/subj04/OWFA -> Dataset (8302, 320)
# train/neural_data/subj04/PPA -> Dataset (8302, 600)
# train/neural_data/subj04/RSC -> Dataset (8302, 497)
# train/neural_data/subj04/V1d -> Dataset (8302, 318)
# train/neural_data/subj04/V1v -> Dataset (8302, 403)
# train/neural_data/subj04/V2d -> Dataset (8302, 319)
# train/neural_data/subj04/V2v -> Dataset (8302, 412)
# train/neural_data/subj04/V3d -> Dataset (8302, 276)
# train/neural_data/subj04/V3v -> Dataset (8302, 378)
# train/neural_data/subj04/VWFA-1 -> Dataset (8302, 425)
# train/neural_data/subj04/VWFA-2 -> Dataset (8302, 12)
# train/neural_data/subj04/early -> Dataset (8302, 2794)
# train/neural_data/subj04/hV4 -> Dataset (8302, 389)
# train/neural_data/subj04/lateral -> Dataset (8302, 1893)
# train/neural_data/subj04/midlateral -> Dataset (8302, 517)
# train/neural_data/subj04/midparietal -> Dataset (8302, 446)
# train/neural_data/subj04/midventral -> Dataset (8302, 706)
# train/neural_data/subj04/nsdgeneral -> Dataset (8302, 9945)
# train/neural_data/subj04/parietal -> Dataset (8302, 916)
# train/neural_data/subj04/ventral -> Dataset (8302, 2648)
# train/neural_data/subj04/whole_brain -> Dataset (8302, 25516)
# train/neural_data/subj05 -> Group
# train/neural_data/subj05/EBA -> Dataset (9000, 2549)
# train/neural_data/subj05/FBA-1 -> Dataset (9000, 412)
# train/neural_data/subj05/FBA-2 -> Dataset (9000, 256)
# train/neural_data/subj05/FFA-1 -> Dataset (9000, 391)
# train/neural_data/subj05/FFA-2 -> Dataset (9000, 238)
# train/neural_data/subj05/OFA -> Dataset (9000, 688)
# train/neural_data/subj05/OPA -> Dataset (9000, 1084)
# train/neural_data/subj05/OWFA -> Dataset (9000, 389)
# train/neural_data/subj05/PPA -> Dataset (9000, 857)
# train/neural_data/subj05/RSC -> Dataset (9000, 480)
# train/neural_data/subj05/V1d -> Dataset (9000, 540)
# train/neural_data/subj05/V1v -> Dataset (9000, 386)
# train/neural_data/subj05/V2d -> Dataset (9000, 463)
# train/neural_data/subj05/V2v -> Dataset (9000, 478)
# train/neural_data/subj05/V3d -> Dataset (9000, 389)
# train/neural_data/subj05/V3v -> Dataset (9000, 398)
# train/neural_data/subj05/VWFA-1 -> Dataset (9000, 336)
# train/neural_data/subj05/VWFA-2 -> Dataset (9000, 171)
# train/neural_data/subj05/early -> Dataset (9000, 3487)
# train/neural_data/subj05/hV4 -> Dataset (9000, 472)
# train/neural_data/subj05/lateral -> Dataset (9000, 1874)
# train/neural_data/subj05/midlateral -> Dataset (9000, 543)
# train/neural_data/subj05/midparietal -> Dataset (9000, 496)
# train/neural_data/subj05/midventral -> Dataset (9000, 925)
# train/neural_data/subj05/nsdgeneral -> Dataset (9000, 11120)
# train/neural_data/subj05/parietal -> Dataset (9000, 1020)
# train/neural_data/subj05/ventral -> Dataset (9000, 2737)
# train/neural_data/subj05/whole_brain -> Dataset (9000, 31764)
# train/neural_data/subj06 -> Group
# train/neural_data/subj06/EBA -> Dataset (8481, 3282)
# train/neural_data/subj06/FBA-1 -> Dataset (8481, 905)
# train/neural_data/subj06/FBA-2 -> Dataset (8481, 225)
# train/neural_data/subj06/FFA-1 -> Dataset (8481, 290)
# train/neural_data/subj06/FFA-2 -> Dataset (8481, 337)
# train/neural_data/subj06/OFA -> Dataset (8481, 473)
# train/neural_data/subj06/OPA -> Dataset (8481, 1169)
# train/neural_data/subj06/OWFA -> Dataset (8481, 482)
# train/neural_data/subj06/PPA -> Dataset (8481, 904)
# train/neural_data/subj06/RSC -> Dataset (8481, 502)
# train/neural_data/subj06/V1d -> Dataset (8481, 692)
# train/neural_data/subj06/V1v -> Dataset (8481, 365)
# train/neural_data/subj06/V2d -> Dataset (8481, 536)
# train/neural_data/subj06/V2v -> Dataset (8481, 512)
# train/neural_data/subj06/V3d -> Dataset (8481, 589)
# train/neural_data/subj06/V3v -> Dataset (8481, 471)
# train/neural_data/subj06/VWFA-1 -> Dataset (8481, 561)
# train/neural_data/subj06/VWFA-2 -> Dataset (8481, 316)
# train/neural_data/subj06/early -> Dataset (8481, 4646)
# train/neural_data/subj06/hV4 -> Dataset (8481, 400)
# train/neural_data/subj06/lateral -> Dataset (8481, 2398)
# train/neural_data/subj06/midlateral -> Dataset (8481, 1021)
# train/neural_data/subj06/midparietal -> Dataset (8481, 726)
# train/neural_data/subj06/midventral -> Dataset (8481, 1089)
# train/neural_data/subj06/nsdgeneral -> Dataset (8481, 15199)
# train/neural_data/subj06/parietal -> Dataset (8481, 1341)
# train/neural_data/subj06/ventral -> Dataset (8481, 3923)
# train/neural_data/subj06/whole_brain -> Dataset (8481, 40468)
# train/neural_data/subj07 -> Group
# train/neural_data/subj07/EBA -> Dataset (9000, 1886)
# train/neural_data/subj07/FBA-1 -> Dataset (9000, 0)
# train/neural_data/subj07/FBA-2 -> Dataset (9000, 230)
# train/neural_data/subj07/FFA-1 -> Dataset (9000, 240)
# train/neural_data/subj07/FFA-2 -> Dataset (9000, 5)
# train/neural_data/subj07/OFA -> Dataset (9000, 234)
# train/neural_data/subj07/OPA -> Dataset (9000, 941)
# train/neural_data/subj07/OWFA -> Dataset (9000, 473)
# train/neural_data/subj07/PPA -> Dataset (9000, 480)
# train/neural_data/subj07/RSC -> Dataset (9000, 355)
# train/neural_data/subj07/V1d -> Dataset (9000, 514)
# train/neural_data/subj07/V1v -> Dataset (9000, 429)
# train/neural_data/subj07/V2d -> Dataset (9000, 346)
# train/neural_data/subj07/V2v -> Dataset (9000, 451)
# train/neural_data/subj07/V3d -> Dataset (9000, 279)
# train/neural_data/subj07/V3v -> Dataset (9000, 283)
# train/neural_data/subj07/VWFA-1 -> Dataset (9000, 265)
# train/neural_data/subj07/VWFA-2 -> Dataset (9000, 446)
# train/neural_data/subj07/early -> Dataset (9000, 2825)
# train/neural_data/subj07/hV4 -> Dataset (9000, 281)
# train/neural_data/subj07/lateral -> Dataset (9000, 1816)
# train/neural_data/subj07/midlateral -> Dataset (9000, 513)
# train/neural_data/subj07/midparietal -> Dataset (9000, 344)
# train/neural_data/subj07/midventral -> Dataset (9000, 578)
# train/neural_data/subj07/nsdgeneral -> Dataset (9000, 9118)
# train/neural_data/subj07/parietal -> Dataset (9000, 882)
# train/neural_data/subj07/ventral -> Dataset (9000, 2146)
# train/neural_data/subj07/whole_brain -> Dataset (9000, 20513)
# train/neural_data/subj08 -> Group
# train/neural_data/subj08/EBA -> Dataset (8302, 1762)
# train/neural_data/subj08/FBA-1 -> Dataset (8302, 303)
# train/neural_data/subj08/FBA-2 -> Dataset (8302, 307)
# train/neural_data/subj08/FFA-1 -> Dataset (8302, 432)
# train/neural_data/subj08/FFA-2 -> Dataset (8302, 389)
# train/neural_data/subj08/OFA -> Dataset (8302, 199)
# train/neural_data/subj08/OPA -> Dataset (8302, 934)
# train/neural_data/subj08/OWFA -> Dataset (8302, 414)
# train/neural_data/subj08/PPA -> Dataset (8302, 571)
# train/neural_data/subj08/RSC -> Dataset (8302, 260)
# train/neural_data/subj08/V1d -> Dataset (8302, 410)
# train/neural_data/subj08/V1v -> Dataset (8302, 372)
# train/neural_data/subj08/V2d -> Dataset (8302, 329)
# train/neural_data/subj08/V2v -> Dataset (8302, 401)
# train/neural_data/subj08/V3d -> Dataset (8302, 285)
# train/neural_data/subj08/V3v -> Dataset (8302, 331)
# train/neural_data/subj08/VWFA-1 -> Dataset (8302, 552)
# train/neural_data/subj08/VWFA-2 -> Dataset (8302, 20)
# train/neural_data/subj08/early -> Dataset (8302, 2431)
# train/neural_data/subj08/hV4 -> Dataset (8302, 340)
# train/neural_data/subj08/lateral -> Dataset (8302, 1508)
# train/neural_data/subj08/midlateral -> Dataset (8302, 425)
# train/neural_data/subj08/midparietal -> Dataset (8302, 302)
# train/neural_data/subj08/midventral -> Dataset (8302, 570)
# train/neural_data/subj08/nsdgeneral -> Dataset (8302, 8424)
# train/neural_data/subj08/parietal -> Dataset (8302, 775)
# train/neural_data/subj08/ventral -> Dataset (8302, 2404)
# train/neural_data/subj08/whole_brain -> Dataset (8302, 13610)
# train/stimulus_ids -> Group
# train/stimulus_ids/subj01 -> Dataset (9000,)
# train/stimulus_ids/subj02 -> Dataset (9000,)
# train/stimulus_ids/subj03 -> Dataset (8481,)
# train/stimulus_ids/subj04 -> Dataset (8302,)
# train/stimulus_ids/subj05 -> Dataset (9000,)
# train/stimulus_ids/subj06 -> Dataset (8481,)
# train/stimulus_ids/subj07 -> Dataset (9000,)
# train/stimulus_ids/subj08 -> Dataset (8302,)

# %% [markdown]
# ---

# %% [markdown]
# # 1. Inspection, Visualization, and Noise Ceiling Estimates
#
# This section is about understanding the data before doing model comparison. By the end of it, you should have a clear sense of how each modality is organized, which signals appear reliable, and how the provided reliability estimates relate to your own computations.

# %% [markdown]
# ## 1.1 Inspect the datasets

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - Inspect the content and axis meaning of TVSD, EEG2, and NSD.
# - Identify where subject IDs, ROI labels, time axes, stimulus IDs, and noise ceilings are stored.
# - State clearly what each axis means for each response array.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **TVSD structure table**
# 2. **EEG2 structure table**
# 3. **NSD structure table**
#
# Each table must list the array name, array shape, and the meaning of each axis.

# %%
# TODO: inspect TVSD
# TODO: inspect EEG2
# TODO: inspect NSD
# TODO: summarize axis meaning

# %%
path_tvsd = '/shared/NX-414/data/tvsd.h5'
path_eeg2 = '/shared/NX-414/data/things_eeg2.h5'
path_nsd = '/shared/NX-414/data/nsd_func1pt8mm_individualROIs.h5'

# %%
def explore_keys(data, key):
    keys = data.keys()
    for 
    try: 
        print(data[key].keys())
        for new_key in data[key].keys():
            explore_key(data, new_key)
    except AttributeError: 
        return data[key].shape, data[key].dtype

with h5py.File(path_tvsd, 'r') as f:
# Out:
#   Cell In[4], line 3
#     for
#         ^
# SyntaxError: invalid syntax

# %%
with h5py.File(path_tvsd, 'r') as f:
    # List all root groups/datasets
    print(list(f.keys()))
    
    # Access a specific dataset
    dset = f['train']
    print(dset.keys())
    print(dset['neural_data']['monkeyF']['IT'].dtype)
    # Check dataset shape and data type
    # print(dset.shape)
    # print(dset.dtype)
# Out:
# ['noise_ceilings', 'test', 'train']
# <KeysViewHDF5 ['neural_data', 'stimulus_ids']>
# float64

# %% [markdown]
# Data exploration:

# %% [markdown]
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 1.1</strong><br>Explain the main differences between the three modalities in terms of what is being measured and how the data are organized.</div>

# %% [markdown]
# ---

# %% [markdown]
# ## 1.2 Visualize EEG signals

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - Plot example EEG responses for several stimuli and channels.
# - Plot average responses over time for at least one subject and one ROI.
# - Visualize the provided EEG noise ceilings over channels and time.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **One plot of example EEG time courses** for several stimuli and channels.
# 2. **One heatmap over channels × time** for at least one subject and one ROI.
# 3. **One summary plot of the provided EEG noise ceilings**.
# 4. **One short written interpretation** in Answer box 1.2.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 1.2</strong><br>Which time windows and channel groups appear most informative? Are the responses dominated by noise, or do you observe clear evoked structure?</div>

# %%
# TODO: load one EEG subject / ROI
# TODO: plot example traces
# TODO: plot channel x time heatmap
# TODO: visualize provided EEG noise ceilings

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt

time_ms = np.linspace(0, 800, 80)
sub = 'sub-03'
roi = 'whole_brain' 

with h5py.File('/shared/NX-414/data/things_eeg2.h5', 'r') as f:
    eeg_test = f['test']['neural_data'][sub][roi][:]  # (200, 63, 80)

stim_ids = [0, 10, 30, 60, 100, 150]
ch_ids   = [0,  5, 15, 25,  40,  55]

fig, axes = plt.subplots(2, 3, figsize=(12, 6), sharex=True, sharey=True)
for i, ax in enumerate(axes.flat):
    s, ch = stim_ids[i], ch_ids[i]
    ax.plot(time_ms, eeg_test[s, ch, :], linewidth=1.5)
    ax.axvline(0, color='gray', linestyle='--', linewidth=0.8)
    ax.set_title(f"Stim {s}, Ch {ch}", fontsize=9)
    if i >= 3: ax.set_xlabel("Time (ms)")
    if i % 3 == 0: ax.set_ylabel("Amplitude (µV)")

fig.suptitle("EEG Time Courses — sub-03, whole_brain ROI", fontsize=13)
plt.tight_layout()
plt.savefig("eeg_timecourses.png", dpi=150)
plt.show()

# %%
for subjj in ['sub-01','sub-02', 'sub-03', 'sub-04', 'sub-05']:
    
    with h5py.File('/shared/NX-414/data/things_eeg2.h5', 'r') as f:
        eeg_train = f['train']['neural_data'][subjj]['temporal'][:]  # (16540, 63, 80)
    
    avg = eeg_train.mean(axis=0)  # average over all stimuli: (63, 80)
    
    fig, ax = plt.subplots(figsize=(11, 6))
    im = ax.imshow(
        avg,
        aspect='auto',
        origin='lower',
        extent=[time_ms[0], time_ms[-1], 0, avg.shape[0]],
        cmap='RdBu_r'
    )
    plt.colorbar(im, ax=ax, label='Amplitude (µV)')
    ax.set_xlabel("Time (ms)")
    ax.set_ylabel("Channel index (whole_brain)")
    ax.set_title("Avg EEG Response — " + subjj +", temporal ROI")
    plt.tight_layout()
    plt.savefig("eeg_heatmap.png", dpi=150)
    plt.show()

# %%
for subjj in ['sub-01','sub-02', 'sub-03', 'sub-04', 'sub-05']:
    
    with h5py.File('/shared/NX-414/data/things_eeg2.h5', 'r') as f:
        nc = f['noise_ceilings'][subjj]['temporal'][:]  # (63, 80)
    
    fig, ax = plt.subplots(figsize=(11, 6))
    im = ax.imshow(
        nc,
        aspect='auto',
        origin='lower',
        extent=[time_ms[0], time_ms[-1], 0, nc.shape[0]],
        cmap='viridis',
        vmin=0, vmax=1
    )
    
    plt.colorbar(im, ax=ax, label='Noise Ceiling')
    ax.set_xlabel("Time (ms)")
    ax.set_ylabel("Channel index (whole_brain)")
    ax.set_title("EEG Noise Ceilings — " + subjj +", temporal ROI")
    plt.tight_layout()
    plt.savefig("eeg_noise_ceiling.png", dpi=150)
    plt.show()

# %% [markdown]
# ---

# %% [markdown]
# ## 1.3 Estimate EEG noise ceilings using two methods
#
# In practice, there are multiple ways to estimate noise ceilings, depending on the available data and the specific research question. When you have repeated measurements of the same stimulus, you can estimate reliability from the consistency of those repetitions. When repeated measurements are not available, reliability can instead be estimated across subjects, which often yields a more conservative ceiling.
#
# In this part, you will implement two different estimators using the `things_eeg2-test_reps.h5` file, which contains the unaveraged test responses with repetitions.
#
# You must implement **two different estimators** using `things_eeg2-test_reps.h5`. You can refer to the cited paper in each method's docstring for details.

# %% [markdown]
# ### Required estimators
#
# 1. **Variance-based estimator**
# 2. **Split-half reliability estimator**

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - Implement both estimators.
# - Compute both estimators for EEG2.
# - Compare them to the provided EEG noise ceilings stored in `things_eeg2.h5`.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **Working implementation of the variance-based estimator**
# 2. **Working implementation of the split-half estimator**
# 3. **One plot of mean noise ceiling over time**
# 4. **One plot of mean noise ceiling over channels**
# 5. **At least one channel × time heatmap for each estimator**
# 6. **At least one histogram comparing the value distributions**
# 7. **One direct visual comparison to the stored EEG noise ceilings**

# %% [markdown]
# ### Starter functions

# %%
import numpy as np


def compute_ceiling_variancebased(responses: np.ndarray, nan_policy: str = 'omit') -> np.ndarray:
    """
    Noise ceiling per unit using the method described in the NSD paper
    (Allen et al., 2021 / 2022 style variance-based estimator).

    Steps:
      1) z-score across stimuli (axis=1) for each (unit, rep) -> total var ≈ 1
      2) estimate noise variance across repetitions (axis=2), then average across stimuli
      3) signal variance = 1 - noise_var
      4) reliability (percent) for finite repeats:
             nc = 100 * (snr / (snr + 1 / n_reps))

    Parameters
    ----------
    responses : np.ndarray
        Shape (n_units, n_stimuli, n_reps) or
        (n_channels, n_timepoints, n_stimuli, n_reps).
    nan_policy : {'propagate', 'raise', 'omit'}, default='omit'
        Passed to the z-scoring logic when handling NaNs.

    Returns
    -------
    np.ndarray
        Per-unit noise ceilings in percent with shape (n_units,) or
        (n_channels, n_timepoints), depending on your implementation.
    """

    ### TODO
    pass


def compute_ceiling_splithalf(
    responses: np.ndarray,
    folds: int = 10,
    seed: int = 0,
    spearman_brown: bool = True,
    equalize_halves: bool = True,
    clip_folds: bool = False
) -> np.ndarray:
    """
    Split-half reliability per unit (voxel / channel / channel*timepoint).
    You can refer to van Bree et al. (2025) for mathematical details.
    
    Steps:
      1) For each fold, randomly split repetitions into two halves.
      2) Average responses within each half and compute Pearson correlation across stimuli.
      3) Optionally apply Spearman-Brown correction to each fold's correlation.
      4) Average across folds to get a final reliability estimate.

    Parameters
    ----------
    responses : np.ndarray
        Shape (n_units, n_stimuli, n_reps) or
        (n_channels, n_timepoints, n_stimuli, n_reps).
        The last axis corresponds to repetitions / trials.
    folds : int, default=10
        Number of random split-halves to sample.
    seed : int, default=0
        Base RNG seed; each fold may use seed + fold_idx.
    spearman_brown : bool, default=True
        Apply Spearman-Brown correction:
            r_sb = 2r / (1 + r)
    equalize_halves : bool, default=True
        If True, use equal-sized halves and drop one trial if n_reps is odd.
        If False, the second half may be larger by one trial.
    clip_folds : bool, default=False
        If True, clip reliability values after correction.

    Returns
    -------
    np.ndarray
        Array of shape (n_units) or (n_channels, n_timepoints).
    """
    ### TODO
    pass

# %%
# TODO: load repeated EEG test responses
# TODO: compute variance-based estimator
# TODO: compute split-half estimator
# TODO: visualize and compare both estimators

# %% [markdown]
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 1.3</strong><br>Compare the two estimators. Do they produce similar patterns across channels and time? Where do they differ most?</div>

# %% [markdown]
# ---

# %% [markdown]
# ## 1.4 Compare the noise ceiling estimators statistically on EEG2
#
# In `things_eeg2.h5`, we provided noise ceilings computed using one of the two methods you implemented. Can you determine which one it is by comparing the stored ceilings to your computed ones?
#
# Perform a hypothesis test to compare the stored ceilings to each of your computed estimators. For example, you could compute the mean squared error between the stored ceilings and each estimator per subject/time/channel, and then use a paired t-test to see if one estimator is significantly closer to the stored values than the other.

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - State clearly what each estimator assumes.
# - Define a quantitative comparison to the stored EEG noise ceilings.
# - Run at least one simple statistical test or formal comparison.
#
# Examples:
#
# - mean absolute deviation from the stored values,
# - paired comparison across channel × time units,
# - correlation with the stored values.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **One quantitative comparison table** comparing both estimators to the stored EEG noise ceilings.
# 2. **One statistical test or one formal quantitative comparison** such as a paired test, correlation analysis, or mean absolute deviation analysis.
# 3. **One concise written conclusion** stating which estimator better matches the stored values and why.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 1.4</strong><br>Which estimator is more likely to have been used to generate the stored EEG noise ceilings? Justify your answer with both visual and quantitative evidence.</div>

# %%
# TODO: define estimator comparison metric
# TODO: run statistical comparison
# TODO: summarize which estimator best matches stored values

# %% [markdown]
# ---

# %% [markdown]
# ## 1.5 Convert NSD ncsnr to noise ceiling and visualize it on cortex
#
# Some datasets, such as NSD, provide reliability estimates with the data release. In this section, you will visualize the provided NSD reliability estimates on the cortical surface and convert them into noise ceilings for later use in predictive analyses.
#
# The provided NSD reliability estimates are stored as **ncsnr** values on the fsaverage surface. To use them as noise ceilings for voxel-wise analyses, you need to convert ncsnr to noise ceiling using the formula provided in the NSD methods paper.
#
# Parcellations and atlases provide group-level anatomical labels for brain regions. They are often defined on a standard surface or volume space (e.g., fsaverage, MNI) and can be used to summarize or interpret neural data. For this exercise, use the Destrieux atlas to anatomically label the regions with the highest and lowest noise ceilings. It is available in fsaverage space and can be accessed through `nilearn`. Compute the average noise ceiling within each atlas region and identify which regions have the highest and lowest reliability.
#
# If the available atlas is in a different surface resolution (e.g. `fsaverage5`), you can interpolate either the atlas or the noise ceiling map to the same space before visualization. Prefer downsampling rather than upsampling to avoid introducing artificial precision.
#
# You can use `nibabel` to load the `.mgh` files and `nilearn` to visualize the resulting noise ceiling on the fsaverage surface.

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - Load the provided `.mgh` files for subject 01.
# - Convert **ncsnr** to a **noise ceiling estimate** using the formula described in the NSD paper.
# - Visualize the resulting noise ceiling on the fsaverage surface.
# - Overlay a cortical parcellation.
# - Compute parcel-wise average values.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **One histogram of ncsnr values**
# 2. **One cortical surface plot** of ncsnr or the derived noise ceiling
# 3. **One cortical surface plot with parcel overlay**
# 4. **One parcel-wise summary figure or one parcel-wise summary table**
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 1.5</strong><br>Which cortical regions appear most reliable, and which appear least reliable? Explain how the parcellation helps interpret the surface maps.</div>

# %%
# TODO: load lh/rh ncsnr maps
# TODO: convert ncsnr to noise ceiling
# TODO: plot histogram
# TODO: visualize on fsaverage
# TODO: compute parcel-wise summary

# %% [markdown]
# ---

# %% [markdown]
# # 2. Brain–Model Alignment
#
# In this section, you will compare neural responses and model features using **both representational metrics and predictive linear models**. You must complete both parts of this section. The goal is not only to report scores, but also to compare what different metrics reveal about model–brain alignment.

# %% [markdown]
# ## 2.1 Representational alignment: RSA
#
# RSA stands for representational similarity analysis. It is one of the most widely used analyses in fMRI and model–brain alignment research. It compares the geometry of two representational spaces through their representational dissimilarity matrices (RDMs). Given two response matrices, `X` and `Y`, with rows corresponding to the same stimuli, we first compute an RDM for each matrix using correlation distance:
#
# $$
# D^X_{ij} = 1 - \mathrm{corr}(X[i,:], X[j,:]),
# \qquad
# D^Y_{ij} = 1 - \mathrm{corr}(Y[i,:], Y[j,:]),
# $$
#
# for stimulus pairs $i \neq j$.
#
# We then vectorize the upper triangle of each RDM and compute RSA as the Spearman correlation between these two vectors:
#
# $$
# \mathrm{RSA}(X, Y)
# =
# \rho_{\mathrm{Spearman}}
# \left(
# \mathrm{vec}(D^X),\,
# \mathrm{vec}(D^Y)
# \right).
# $$
#
# In this project, `X` will usually denote model features from one candidate layer, and `Y` will denote neural responses from one dataset, ROI, subject, or time slice, depending on the analysis.
#
# - Implement RSA between two representation matrices.
# - Support at least one dissimilarity measure and one similarity measure.
# - Use your implementation to compare model layers to neural responses.

# %% [markdown]
# ### Starter code

# %%
from typing import Literal
import numpy as np
from scipy.stats import pearsonr, spearmanr
from scipy.spatial.distance import pdist, squareform


class RepresentationalSimilarityAnalysis:
    """
    Representational Similarity Analysis (RSA).

    Given two representation matrices X and Y with the same number of conditions
    (rows), RSA:

    1. Computes a Representational Dissimilarity Matrix (RDM) for each:
       RDM_X[i, j] = dissimilarity(x_i, x_j)
       RDM_Y[i, j] = dissimilarity(y_i, y_j)

    2. Flattens the upper triangles of both RDMs and computes a correlation
       between them (Pearson or Spearman).
    """

    def __init__(
        self,
        dissimilarity: Literal["correlation", "euclidean", "cosine"] = "correlation",
        similarity_metric: Literal["pearson", "spearman"] = "spearman",
    ):
        assert dissimilarity in ("correlation", "euclidean", "cosine"), \
            f"Unknown dissimilarity: {dissimilarity}"
        assert similarity_metric in ("pearson", "spearman"), \
            f"Unknown similarity_metric: {similarity_metric}"

        self.dissimilarity = dissimilarity
        self.similarity_metric = similarity_metric

    def __call__(self, X: np.ndarray, Y: np.ndarray) -> float:
        """
        Compute RSA similarity between X and Y.

        Parameters
        ----------
        X, Y : np.ndarray
            Arrays of shape (n_conditions, ...) that may need to be flattened
            along feature dimensions.

        Returns
        -------
        rsa_similarity : float
            Correlation between the vectorized upper triangles of the two RDMs.
        """
        return self.forward(X, Y)

    def forward(self, X: np.ndarray, Y: np.ndarray) -> float:
        # Flatten any extra dimensions beyond the first (stimulus) axis
        # e.g. EEG shape (n_stimuli, n_channels, n_timepoints) → (n_stimuli, n_channels*n_timepoints)
        X = X.reshape(X.shape[0], -1)
        Y = Y.reshape(Y.shape[0], -1)

        assert X.shape[0] == Y.shape[0], \
            f"X and Y must have the same number of conditions. Got {X.shape[0]} vs {Y.shape[0]}"

        rdm_x = self.compute_rdm(X)
        rdm_y = self.compute_rdm(Y)

        return self.compare_rdms(rdm_x, rdm_y)

    def compute_rdm(self, X: np.ndarray) -> np.ndarray:
        """
        Compute the Representational Dissimilarity Matrix (RDM)
        for a given representation matrix X.

        Parameters
        ----------
        X : np.ndarray
            Array of shape (n_conditions, n_features).

        Returns
        -------
        rdm : np.ndarray
            Array of shape (n_conditions, n_conditions) with pairwise dissimilarities.
        """
        # pdist computes all pairwise distances in condensed form, then
        # squareform converts to full symmetric matrix.
        # 'correlation' distance = 1 - Pearson(x_i, x_j), exactly as defined above.
        condensed = pdist(X, metric=self.dissimilarity)
        rdm = squareform(condensed)  # shape: (n_conditions, n_conditions)
        return rdm

    def compare_rdms(self, rdm1: np.ndarray, rdm2: np.ndarray) -> float:
        """
        Compare two RDMs by correlating their upper triangles.
        """
        n = rdm1.shape[0]
        # Extract upper triangle indices (k=1 excludes the diagonal)
        triu_idx = np.triu_indices(n, k=1)

        vec1 = rdm1[triu_idx]
        vec2 = rdm2[triu_idx]

        if self.similarity_metric == "spearman":
            r, _ = spearmanr(vec1, vec2)
        else:  # pearson
            r, _ = pearsonr(vec1, vec2)

        return float(r)

# %% [markdown]
# ## 2.2 Representational alignment: unbiased linear CKA
#
# CKA stands for centered kernel alignment. It is commonly used in interpretability and representation analysis to test how strongly the internal computations of two systems align. As a second mapping-free alignment metric, we want to compute unbiased linear centered kernel alignment (CKA) between model features and neural responses. Let
#
# $$
# X \in \mathbb{R}^{n \times d}, \qquad
# Y \in \mathbb{R}^{n \times p},
# $$
#
# where both matrices are measured on the same $n$ stimuli. We form linear Gram matrices
#
# $$
# K = XX^\top,
# \qquad
# L = YY^\top.
# $$
#
# We then estimate dependence using the unbiased (U-statistic) HSIC estimator, $\mathrm{HSIC}_u(K, L)$, and define CKA as
#
# $$
# \mathrm{CKA}(X, Y)
# =
# \frac{\mathrm{HSIC}_u(K, L)}
# {\sqrt{\mathrm{HSIC}_u(K, K)\,\mathrm{HSIC}_u(L, L)}}.
# $$
#
# Like RSA, CKA compares representational structure directly without fitting a predictive mapping. In this notebook, `X` and `Y` again refer to aligned model and neural response matrices evaluated on the same set of stimuli.
#
# - Implement **unbiased linear CKA** only.
# - Use your implementation to compare model layers to neural responses.

# %% [markdown]
# ### Starter code

# %%
import numpy as np


class CenteredKernelAlignment:
    """
    Unbiased linear CKA only.

    Parameters
    ----------
    eps : float
        Small constant for numerical stability in the final division.
    dtype : np.dtype
        Data type used for computations.
    """

    def __init__(
        self,
        eps: float = 1e-8,
        dtype: np.dtype = np.float64,
    ):
        self.eps = eps
        self.dtype = dtype

    def __call__(self, X: np.ndarray, Y: np.ndarray) -> float:
        return self.forward(X, Y)

    def forward(self, X: np.ndarray, Y: np.ndarray) -> float:
        X = np.asarray(X).astype(self.dtype)
        Y = np.asarray(Y).astype(self.dtype)

        if X.shape[0] != Y.shape[0]:
            raise ValueError(
                f"Batch sizes must match along axis 0: {X.shape[0]} vs {Y.shape[0]}"
            )

        # Flatten to (n_samples, n_features)
        X = X.reshape(X.shape[0], -1)
        Y = Y.reshape(Y.shape[0], -1)

        return self._unbiased_linear_cka(X, Y)

    def _unbiased_linear_hsic(self, K: np.ndarray, L: np.ndarray) -> float:
        """
        Unbiased HSIC estimator (Kornblith et al. 2019) for two Gram matrices.

        The estimator zeroes out the diagonal of K and L to remove the bias
        introduced by the self-similarity terms, then computes:

            HSIC_u(K, L) = 1 / (n*(n-3)) * [
                tr(K_tilde @ L_tilde)
                + (1^T K_tilde 1)(1^T L_tilde 1) / ((n-1)*(n-2))
                - 2/(n-2) * 1^T K_tilde L_tilde 1
            ]

        Parameters
        ----------
        K, L : np.ndarray
            Gram matrices of shape (n, n). These are the raw (non-centered)
            linear kernel matrices K = X @ X.T and L = Y @ Y.T.

        Returns
        -------
        hsic : float
        """
        n = K.shape[0]
        assert n > 3, "Need n > 3 for the unbiased estimator to be defined."

        # Zero out diagonals — this is the key step that removes bias
        K_tilde = K.copy()
        L_tilde = L.copy()
        np.fill_diagonal(K_tilde, 0.0)
        np.fill_diagonal(L_tilde, 0.0)

        # Term 1: tr(K_tilde @ L_tilde)
        # Equivalent to np.sum(K_tilde * L_tilde) (element-wise, since tr(A@B) = sum(A*B.T) = sum(A*B) for symmetric)
        term1 = np.sum(K_tilde * L_tilde)

        # Term 2: (1^T K_tilde 1)(1^T L_tilde 1) / ((n-1)(n-2))
        # 1^T K_tilde 1 = sum of all elements of K_tilde
        sum_K = K_tilde.sum()
        sum_L = L_tilde.sum()
        term2 = (sum_K * sum_L) / ((n - 1) * (n - 2))

        # Term 3: 2/(n-2) * 1^T (K_tilde @ L_tilde) 1
        # 1^T (K_tilde @ L_tilde) 1 = sum of all elements of (K_tilde @ L_tilde)
        term3 = (2.0 / (n - 2)) * np.sum(K_tilde @ L_tilde)

        hsic = (term1 + term2 - term3) / (n * (n - 3))
        return float(hsic)

    def _unbiased_linear_cka(self, X: np.ndarray, Y: np.ndarray) -> float:
        """
        Unbiased linear CKA:

            CKA_unb(X, Y) =
                HSIC_unb(K, L) / sqrt(HSIC_unb(K, K) * HSIC_unb(L, L))

        where K = X @ X.T and L = Y @ Y.T are the linear Gram matrices.
        """
        # Build linear Gram matrices
        K = X @ X.T   # (n, n)
        L = Y @ Y.T   # (n, n)

        hsic_xy = self._unbiased_linear_hsic(K, L)
        hsic_xx = self._unbiased_linear_hsic(K, K)
        hsic_yy = self._unbiased_linear_hsic(L, L)

        # Normalise — clamp denominator to eps for numerical safety
        denom = np.sqrt(hsic_xx * hsic_yy)
        cka = hsic_xy / (denom + self.eps)

        return float(cka)

# %% [markdown]
# ## 2.3 Apply RSA and CKA

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# - Compare layers within each model.
# - Compare the two models.
# - For EEG, show how representational similarity changes over time.
# - For TVSD and NSD, compare across ROIs.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **Layer-wise RSA results** for both models.
# 2. **Layer-wise CKA results** for both models.
# 3. **One direct comparison between the two models** using representational metrics.
# 4. **One EEG time-resolved analysis** or **one ROI-wise analysis** for TVSD/NSD.
# 5. **One short written interpretation** in Answer box 2.1.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 2.1</strong><br>Do RSA and CKA tell the same story? Identify at least one case where they agree and one case where they disagree, and explain what that might mean.</div>

# %%
import os, glob

# Search common locations for model feature files
for pattern in [
    '/shared/NX-414/**/*stimuli*',
    '/shared/NX-414/**/*features*',
    '/shared/NX-414/**/*resnet*',
    '/shared/NX-414/**/*qwen*',
]:
    results = glob.glob(pattern, recursive=True)
    if results:
        print(pattern, '→', results)
# Out:
# /shared/NX-414/**/*stimuli* → ['/shared/NX-414/extracted_features/adv_resnet152_imagenet_full_ffgsm_eps-1_alpha-125-ep10_seed-0/things_stimuli.h5', '/shared/NX-414/extracted_features/adv_resnet152_imagenet_full_ffgsm_eps-1_alpha-125-ep10_seed-0/nsd_stimuli.h5', '/shared/NX-414/extracted_features/Qwen3-VL-2B-Instruct/nsd_stimuli.h5', '/shared/NX-414/extracted_features/Qwen3-VL-2B-Instruct/things_stimuli.h5']
# /shared/NX-414/**/*features* → ['/shared/NX-414/extracted_features']
# /shared/NX-414/**/*resnet* → ['/shared/NX-414/extracted_features/adv_resnet152_imagenet_full_ffgsm_eps-1_alpha-125-ep10_seed-0']

# %%
import h5py
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import spearmanr
from scipy.spatial.distance import pdist, squareform

FEAT_BASE = '/shared/NX-414/extracted_features'
DATA_BASE = '/shared/NX-414/data'

PATH_RESNET_THINGS = f'{FEAT_BASE}/adv_resnet152_imagenet_full_ffgsm_eps-1_alpha-125-ep10_seed-0/things_stimuli.h5'
PATH_RESNET_NSD    = f'{FEAT_BASE}/adv_resnet152_imagenet_full_ffgsm_eps-1_alpha-125-ep10_seed-0/nsd_stimuli.h5'
PATH_QWEN_THINGS   = f'{FEAT_BASE}/Qwen3-VL-2B-Instruct/things_stimuli.h5'
PATH_QWEN_NSD      = f'{FEAT_BASE}/Qwen3-VL-2B-Instruct/nsd_stimuli.h5'
PATH_EEG           = f'{DATA_BASE}/things_eeg2.h5'
PATH_NSD           = f'{DATA_BASE}/nsd_func1pt8mm_individualROIs.h5'
PATH_TVSD          = f'{DATA_BASE}/tvsd.h5'

# --- EEG ---
with h5py.File(PATH_EEG, 'r') as f:
    eeg_test_ids = f['test']['stimulus_ids'][:]
    eeg = {roi: f['test']['neural_data']['sub-01'][roi][:]
           for roi in ['occipital', 'temporal', 'parietal', 'frontal', 'whole_brain']}
    eeg_nc = {roi: f['noise_ceilings']['sub-01'][roi][:]
              for roi in ['occipital', 'temporal', 'parietal', 'frontal', 'whole_brain']}

# --- NSD (fMRI) ---
NSD_ROIS = ['V1d', 'V1v', 'hV4', 'EBA', 'FFA-1', 'FFA-2',
            'PPA', 'early', 'ventral', 'lateral', 'whole_brain']
with h5py.File(PATH_NSD, 'r') as f:
    nsd_test_ids = f['test']['stimulus_ids']['subj01'][:]
    nsd = {roi: f['test']['neural_data']['subj01'][roi][:]
           for roi in NSD_ROIS
           if f['test']['neural_data']['subj01'][roi].shape[-1] > 0}
    nsd_nc = {roi: f['noise_ceilings']['subj01'][roi][:]
              for roi in NSD_ROIS
              if f['noise_ceilings']['subj01'][roi].shape[0] > 0}

# --- TVSD (macaque) ---
with h5py.File(PATH_TVSD, 'r') as f:
    tvsd_test_ids = f['test']['stimulus_ids'][:]
    tvsd = {area: f['test']['neural_data']['monkeyF'][area][:]
            for area in ['V1', 'V4', 'IT']}
    tvsd_nc = {area: f['noise_ceilings']['monkeyF'][area][:]
               for area in ['V1', 'V4', 'IT']}

# %%
def load_features(h5_path, test_ids):
    with h5py.File(h5_path, 'r') as f:
        feat_ids = f['ids'][:]
        id_to_row = {v: i for i, v in enumerate(feat_ids)}
        row_idx = np.array([id_to_row[i] for i in test_ids])
        sort_order = np.argsort(row_idx)
        restore_order = np.argsort(sort_order)
        sorted_idx = row_idx[sort_order]
        return {key: f[f'features/{key}'][sorted_idx][restore_order]
                for key in f['features'].keys()}

# Model A: adversarial ResNet-152
model_A_things = load_features(PATH_RESNET_THINGS, eeg_test_ids)   # (200,  30000) per layer
model_A_nsd    = load_features(PATH_RESNET_NSD,    nsd_test_ids)   # (1000, 30000) per layer
model_A_tvsd   = load_features(PATH_RESNET_THINGS, tvsd_test_ids)  # (100,  30000) per layer

# Model B: Qwen3-VL-2B
model_B_things = load_features(PATH_QWEN_THINGS,   eeg_test_ids)
model_B_nsd    = load_features(PATH_QWEN_NSD,      nsd_test_ids)
model_B_tvsd   = load_features(PATH_QWEN_THINGS,   tvsd_test_ids)

# %%
# TODO: implement RSA
# TODO: implement unbiased linear CKA   
# TODO: compute scores across layers
# TODO: compare across models and ROIs / time windows
import h5py
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import pearsonr

# ── Assumes your RSA and CKA classes are already defined ────────────────────
rsa = RepresentationalSimilarityAnalysis(dissimilarity="correlation", similarity_metric="spearman")
cka = CenteredKernelAlignment(eps=1e-8, dtype=np.float64)

rsa_A = [rsa(model_A_features[l], Y_eeg) for l in layers]
rsa_B = [rsa(model_B_features[l], Y_eeg) for l in layers]
cka_A = [cka(model_A_features[l], Y_eeg) for l in layers]
cka_B = [cka(model_B_features[l], Y_eeg) for l in layers]

x = np.arange(len(layers))
width = 0.35

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# RSA
axes[0].bar(x - width/2, rsa_A, width, label='Model A')
axes[0].bar(x + width/2, rsa_B, width, label='Model B')
axes[0].set_xticks(x); axes[0].set_xticklabels(layers, rotation=30, ha='right')
axes[0].set_ylabel("Spearman ρ"); axes[0].set_title("Layer-wise RSA vs EEG (sub-01, whole_brain)")
axes[0].legend()

# CKA
axes[1].bar(x - width/2, cka_A, width, label='Model A')
axes[1].bar(x + width/2, cka_B, width, label='Model B')
axes[1].set_xticks(x); axes[1].set_xticklabels(layers, rotation=30, ha='right')
axes[1].set_ylabel("CKA score"); axes[1].set_title("Layer-wise CKA vs EEG (sub-01, whole_brain)")
axes[1].legend()

plt.tight_layout()
plt.savefig("layerwise_rsa_cka.png", dpi=150)
plt.show()

# Compare the two models head-to-head: does RSA and CKA agree on which model is better?
fig, axes = plt.subplots(1, 2, figsize=(12, 5))

# RSA: Model A vs Model B per layer
axes[0].scatter(rsa_A, rsa_B, s=60, zorder=3)
for i, l in enumerate(layers):
    axes[0].annotate(l, (rsa_A[i], rsa_B[i]), fontsize=8, ha='left')
lims = [min(min(rsa_A), min(rsa_B)) - 0.01, max(max(rsa_A), max(rsa_B)) + 0.01]
axes[0].plot(lims, lims, 'r--', linewidth=1)
axes[0].set_xlabel("Model A RSA"); axes[0].set_ylabel("Model B RSA")
axes[0].set_title("RSA: Model A vs B per layer")

# CKA: Model A vs Model B per layer
axes[1].scatter(cka_A, cka_B, s=60, zorder=3)
for i, l in enumerate(layers):
    axes[1].annotate(l, (cka_A[i], cka_B[i]), fontsize=8, ha='left')
lims = [min(min(cka_A), min(cka_B)) - 0.01, max(max(cka_A), max(cka_B)) + 0.01]
axes[1].plot(lims, lims, 'r--', linewidth=1)
axes[1].set_xlabel("Model A CKA"); axes[1].set_ylabel("Model B CKA")
axes[1].set_title("CKA: Model A vs B per layer")

plt.tight_layout()
plt.savefig("model_comparison_rsa_cka.png", dpi=150)
plt.show()

# For each timepoint, compute RSA/CKA between model features and EEG slice at that time
best_layer = layers[-1]   # use the best-performing layer from plots above
X_model = model_A_features[best_layer]   # (200, n_features)

n_timepoints = 80
time_ms = np.linspace(0, 800, n_timepoints)
rsa_time = np.zeros(n_timepoints)
cka_time = np.zeros(n_timepoints)

for t in range(n_timepoints):
    Y_t = eeg['whole_brain'][:, :, t]   # (200, 63) — one timepoint
    rsa_time[t] = rsa(X_model, Y_t)
    cka_time[t] = cka(X_model, Y_t)

fig, ax = plt.subplots(figsize=(10, 4))
ax.plot(time_ms, rsa_time, label='RSA (Spearman ρ)', linewidth=2)
ax.plot(time_ms, cka_time, label='CKA', linewidth=2, linestyle='--')
ax.axvline(100, color='gray', linestyle=':', linewidth=1, label='100 ms')
ax.axvline(200, color='gray', linestyle=':', linewidth=1, label='200 ms')
ax.set_xlabel("Time (ms)"); ax.set_ylabel("Similarity score")
ax.set_title(f"Time-resolved RSA & CKA — Model A {best_layer} vs EEG (sub-01, whole_brain)")
ax.legend()
plt.tight_layout()
plt.savefig("eeg_time_resolved.png", dpi=150)
plt.show()

# TVSD: RSA and CKA per visual area
tvsd_areas = list(tvsd_test.keys())   # ['V1', 'V4', 'IT']
rsa_tvsd = [rsa(X_model[:len(tvsd_test[a])], tvsd_test[a]) for a in tvsd_areas]
cka_tvsd = [cka(X_model[:len(tvsd_test[a])], tvsd_test[a]) for a in tvsd_areas]

# NSD: RSA and CKA per ROI
nsd_rois = list(nsd_test.keys())
rsa_nsd = [rsa(X_model[:len(nsd_test[r])], nsd_test[r]) for r in nsd_rois]
cka_nsd = [cka(X_model[:len(nsd_test[r])], nsd_test[r]) for r in nsd_rois]

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# TVSD
x = np.arange(len(tvsd_areas)); width = 0.35
axes[0].bar(x - width/2, rsa_tvsd, width, label='RSA')
axes[0].bar(x + width/2, cka_tvsd, width, label='CKA')
axes[0].set_xticks(x); axes[0].set_xticklabels(tvsd_areas)
axes[0].set_ylabel("Score"); axes[0].set_title(f"TVSD ROI-wise — Model A {best_layer}")
axes[0].legend()

# NSD
x = np.arange(len(nsd_rois))
axes[1].bar(x - width/2, rsa_nsd, width, label='RSA')
axes[1].bar(x + width/2, cka_nsd, width, label='CKA')
axes[1].set_xticks(x); axes[1].set_xticklabels(nsd_rois, rotation=30, ha='right')
axes[1].set_ylabel("Score"); axes[1].set_title(f"NSD ROI-wise — Model A {best_layer}")
axes[1].legend()

plt.tight_layout()
plt.savefig("roi_wise_analysis.png", dpi=150)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 83
#      73     nsd_test_ids = {
#      74         subj: f['test']['stimulus_ids'][subj][:]
#      75         for subj in NSD_SUBJS
#      76     }
#      78 # ── model_features: dict of {layer_name: np.ndarray of shape (n_test_stimuli, n_features)}
#      79 # Replace with your actual feature extraction — example structure:
#      80 # model_A_features = {'layer1': ..., 'layer4': ..., 'layer7': ..., 'layer10': ...}
#      81 # model_B_features = {'layer1': ..., 'layer4': ..., 'layer7': ..., 'layer10': ...}
# ---> 83 layers = list(model_A_features.keys())   # same layer names for both models
#      84 Y_eeg  = eeg['whole_brain']              # (200, 63, 80) — flatten handled internally
#      86 rsa_A = [rsa(model_A_features[l], Y_eeg) for l in layers]
#
# NameError: name 'model_A_features' is not defined

# %% [markdown]
# ---

# %% [markdown]
# ## 2.4 Predictive alignment: linear encoding models

# %% [markdown]
# ## Linear encoding model
#
# In the predictive part of the project, you will map model features to neural responses using a **linear encoding model with L2 regularization (ridge regression)**.
#
# For a stimulus $\mathbf{x}$, let $\mathbf{z}_{\ell}(\mathbf{x})$ denote the feature vector extracted from model layer $\ell$. For a given subject $s$ and neural target $r$ (for example an ROI, a group of voxels, or a set of channels / time points), the predicted neural response is
#
# $$
# \widehat{\mathbf{y}}_{r,s}(\mathbf{x})
# =
# W_{r,s}\,\mathbf{z}_{\ell}(\mathbf{x}) + \mathbf{b}_{r,s},
# $$
#
# where:
# - $\mathbf{z}_{\ell}(\mathbf{x}) \in \mathbb{R}^{d}$ is the model feature vector,
# - $\widehat{\mathbf{y}}_{r,s}(\mathbf{x}) \in \mathbb{R}^{p}$ is the predicted neural response,
# - $W_{r,s} \in \mathbb{R}^{p \times d}$ is the learned linear mapping,
# - $\mathbf{b}_{r,s} \in \mathbb{R}^{p}$ is a bias term.
#
# We fit the mapping on the training split using ridge regression:
#
# $$
# \min_{W_{r,s},\,\mathbf{b}_{r,s}}
# \sum_{\mathbf{x}\in\mathcal{D}_{\mathrm{train}}}
# \left\|
# \mathbf{y}_{r,s}(\mathbf{x}) - \widehat{\mathbf{y}}_{r,s}(\mathbf{x})
# \right\|_2^2
# \;+\;
# \alpha \left\|W_{r,s}\right\|_F^2.
# $$
#
# Here, $\mathbf{y}_{r,s}(\mathbf{x})$ is the measured neural response, and $\alpha$ controls the strength of L2 regularization. Larger $\alpha$ penalizes large weights more strongly, which can improve generalization when the feature dimension is high. You should select $\alpha$ using only the training data, for example with a validation split or cross-validation, and then evaluate the final model on the held-out test set.

# %% [markdown]
# <div style="background:#eef8f4; border-left:4px solid #5b9a7a; padding:8px 12px; border-radius:6px; font-weight:700; color:#285943;">Select the required targets</div>
#
# Use the following targets:
#
# - **TVSD:** all ROIs
# - **EEG2:** `occipital_parietal`
# - **NSD:** `V1v`, `V2v`, `V3v`, `hV4`, `FFA-1`, `VWFA-1`, `PPA`, `OPA`, `EBA`
#
# You may explore additional ROIs if you wish.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 2.2</strong><br>Briefly explain why these targets are scientifically interesting. Are they chosen mainly for reliability, interpretability, or both?</div>

# %%
# TODO: define target ROIs / regions
# TODO: load corresponding neural data

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# For each dataset, target, model, and candidate layer:
#
# - fit a **linear encoding model**,
# - select hyperparameters without using the test split,
# - evaluate on the test split.
#
# Use iterative solvers (e.g. SGD, Adam) when needed to avoid memory issues, since `sklearn` Ridge might cause OOM.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **A clearly defined train/validation/test procedure** that does not use the test set for model selection.
# 2. **Linear encoding model results** for all required datasets and targets.
# 3. **The following predictive metrics:** Pearson correlation, noise-corrected Pearson correlation, explained variance, and noise-corrected explained variance.
# 4. **The following hybrid representational metrics on predicted responses:** encoding-RSA and encoding-CKA.
# 5. **Layer-wise plots** showing performance across candidate layers.
# 6. **One best-layer summary table** for the required targets.
# 7. **One comparison between the two models** using predictive results.
# 8. **One short written interpretation** in Answer box 2.3.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 2.3</strong><br>Which model and which layer perform best for each dataset? Summarize the main trends in a short paragraph.</div>

# %%
# TODO: define train/val/test procedure
# TODO: fit linear models across layers
# TODO: compute predictive metrics
# TODO: summarize best layers and best scores

# %% [markdown]
# ---

# %% [markdown]
# ## 2.5 Compare predictive and representational metrics

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# Compare the ranking of models and layers according to:
#
# - Pearson correlation,
# - explained variance,
# - RSA,
# - CKA.
# - encoding-RSA/ encoding-CKA
#
# Discuss whether the same layers are favored by all metrics.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **One figure comparing layer or model rankings across metrics**
# 2. **One concrete example where two metrics agree**
# 3. **One concrete example where two metrics disagree**
# 4. **One short written interpretation** in Answer box 2.4.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 2.4</strong><br>Does a model that is representationally similar to the brain also predict neural responses well? Use at least one example from your results.</div>

# %%
# TODO: compare ranking of layers across metrics
# TODO: identify agreements and disagreements

# %% [markdown]
# ---

# %% [markdown]
# ## 2.6 Relate layer hierarchy to brain hierarchy

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# Test whether deeper layers align better with higher-level neural targets.
#
# - Does TVSD IT align with deeper layers than V1?
# - Do higher-level NSD regions prefer later layers?
# - For EEG, are particular time windows associated with later layers?

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include one of the following analyses:
#
# 1. **A heatmap of layer × ROI**
# 2. **A ranked-layer plot by ROI**
# 3. **A time-resolved EEG layer comparison**
#
# You must also include a short written conclusion in Answer box 2.5 stating whether the results support a hierarchy correspondence.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 2.5</strong><br>Is there evidence for a correspondence between model depth and neural hierarchy? State your conclusion clearly and support it with results.</div>

# %%
# TODO: compare layers across ROIs / time windows
# TODO: create hierarchy figure(s)

# %% [markdown]
# ---

# %% [markdown]
# ## 2.7 Compare the two feature extractors

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must do</div>
#
# Compare **Qwen3-VL-2B-Instruct** and **Adv-ResNet152** across datasets, ROIs, layers, and metrics.

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **One summary figure comparing Qwen3-VL-2B-Instruct and Adv-ResNet152**
# 2. **One table of best scores across datasets and targets**
# 3. **One short written interpretation** in Answer box 2.6.
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 2.6</strong><br>Does the vision-language model provide a clear advantage over the CNN? Is that advantage consistent across modalities and targets?</div>

# %%
# TODO: aggregate results across both models
# TODO: create summary comparison figure/table

# %% [markdown]
# ---

# %% [markdown]
# # 3. Open-Ended Research
#
# So far you have explored a simple encoding model with a linear readout from a single layer per subject/ROI. In this section, you will extend the baseline pipeline in one clearly defined direction. The goal is to explore a meaningful extension that goes beyond the standard linear readout and to evaluate whether it provides a practically meaningful improvement. Depth is more important than breadth: a focused experiment is better than a broad but shallow exploration.
#
# Possible directions include:
#
# - readouts shared across ROIs,
# - readouts shared across subjects,
# - readouts shared across modalities,
# - combining multiple layers,
# - low-rank readouts,
# - nonlinear readouts,
# - temporal readouts for EEG,
# - attention-based readouts,
# - cross-subject pooling.

# %% [markdown]
# ## What you must include
#
# 1. **Question**
#    What are you testing?
#
# 2. **Motivation**
#    Why is this extension interesting?
#
# 3. **Method**
#    What did you change relative to the linear baseline?
#
# 4. **Comparison**
#    How does it compare to the baseline?
#
# 5. **Interpretation**
#    Did it help, and why might that be?

# %% [markdown]
# <div style="background:#f3f6fa; border-left:4px solid #7a93ac; padding:8px 12px; border-radius:6px; font-weight:700; color:#32475b;">Required deliverables</div>
#
# You must include all of the following:
#
# 1. **A clearly stated hypothesis**
# 2. **A short motivation for the extension**
# 3. **A clear description of the new method**
# 4. **One direct comparison against the linear baseline**
# 5. **At least one figure or one table summarizing the comparison**
# 6. **A short discussion of whether the extension helped in a practically meaningful way**
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box 3</strong><br>State your hypothesis, summarize your result, and say whether the new method helped in a practically meaningful way.</div>

# %%
# TODO: define extension
# TODO: implement method
# TODO: compare against linear baseline

# %% [markdown]
# ---

# %% [markdown]
# # Final Discussion
#
# End the notebook with a short final discussion.

# %% [markdown]
# <div style="background:#eef5fb; border-left:4px solid #4c78a8; padding:8px 12px; border-radius:6px; font-weight:700; color:#26445e;">What you must address</div>
#
# - Which dataset appeared noisiest?
# - Which neural targets were most reliable?
# - Which model aligned best overall?
# - Which metrics were most consistent with each other?
# - What was the main limitation of your analysis?
# - What would you try next with more time?
#
# <div style="background:#fff4c2; border:1px solid #c89b1f; border-left:6px solid #9a6f00; padding:10px 12px; border-radius:6px; margin-top:8px; margin-bottom:4px; color:#241a00; line-height:1.45;"><strong style="color:#5c4300;">Answer box final</strong><br>Write a concise final conclusion of 1–2 paragraphs summarizing your main findings and their limitations.</div>

# %%
# No code required here unless you want to add final summary tables/figures.

# %% [markdown]
# ---

# %% [markdown]
# # Report Content
#
# Your **2-page PDF report** should tell a clear and coherent story. It does **not** need to reproduce every notebook result.
#
# It can include:
#
# 1. **A brief dataset overview**
# 2. **An exploratory figure from Section 1**
# 3. **The EEG noise ceiling comparison**
# 4. **The NSD reliability visualization**
# 5. **One or two key brain–model alignment results from Section 2**
#
#
# Rather, you should primarily focus on the open-ended extension you designed, describing:
# - the motivation for your extension,
# - the methods you implemented,
# - the results you obtained,
# - and the scientific insights you gained from it.
#
#
# The report should emphasize interpretation, not just figures. Since the notebook is the main technical deliverable, the report should act as a **compressed scientific summary** of your most important findings rather than a figure dump.
#
# ---

# %% [markdown]
# # Detailed Grading Rubric
#
# The project is graded out of **100 points** as follows:
#
# - **Section 1: Inspection, Visualization, and Noise Ceiling Estimates — 20 points**
# - **Section 2: Brain–Model Alignment — 20 points**
# - **Section 3: Open-Ended Research — 30 points**
# - **Report — 30 points**
#
# **Section 0 is required but not graded separately.** It is treated as setup and reproducibility infrastructure for the rest of the notebook.

# %% [markdown]
# ## Section 1 — 20 points

# %% [markdown]
# ### 1.1 Dataset inspection — 3 points
# - 1 pt: TVSD structure is correctly inspected and explained.
# - 1 pt: EEG2 structure is correctly inspected and explained.
# - 1 pt: NSD structure is correctly inspected and explained.

# %% [markdown]
# ### 1.2 EEG visualization — 4 points
# - 1 pt: example EEG time-course plot is present and readable.
# - 1 pt: channel × time heatmap is present and readable.
# - 1 pt: provided EEG noise ceiling visualization is present and readable.
# - 1 pt: written interpretation identifies informative time windows or channel groups.

# %% [markdown]
# ### 1.3 EEG noise ceiling estimation — 7 points
# - 2 pts: variance-based estimator is implemented correctly.
# - 2 pts: split-half estimator is implemented correctly.
# - 1 pt: required summary visualizations are included.
# - 1 pt: comparison to stored EEG noise ceilings is shown clearly.
# - 1 pt: Answer box 1.3 interprets similarities and differences between estimators.

# %% [markdown]
# ### 1.4 Statistical comparison of EEG noise ceilings — 3 points
# - 1 pt: quantitative comparison table is present.
# - 1 pt: statistical test or formal comparison is appropriate and correctly interpreted.
# - 1 pt: final conclusion is clearly justified.

# %% [markdown]
# ### 1.5 NSD reliability visualization — 3 points
# - 1 pt: ncsnr is correctly converted and visualized on cortex.
# - 1 pt: parcel overlay or parcel-wise summary is included.
# - 1 pt: Answer box 1.5 correctly interprets reliable and unreliable regions.

# %% [markdown]
# ## Section 2 — 20 points

# %% [markdown]
# ### 2.1 RSA implementation — 3 points
# - 1 pt: RDM computation is correct.
# - 1 pt: RDM comparison is correct.
# - 1 pt: implementation is used properly in later analyses.

# %% [markdown]
# ### 2.2 Unbiased linear CKA implementation — 3 points
# - 2 pts: unbiased linear CKA is implemented correctly.
# - 1 pt: implementation is used properly in later analyses.

# %% [markdown]
# ### 2.3 Representational analyses across layers, models, and targets — 4 points
# - 1 pt: layer-wise RSA results are reported clearly.
# - 1 pt: layer-wise CKA results are reported clearly.
# - 1 pt: a model comparison is included.
# - 1 pt: ROI-wise or time-resolved analysis is included and interpreted.

# %% [markdown]
# ### 2.4 Predictive alignment with linear encoding models — 6 points
# - 1 pt: required targets are selected and described correctly.
# - 2 pts: train/validation/test procedure and ridge fitting are correct.
# - 1 pt: required predictive metrics are reported correctly.
# - 1 pt: encoding-RSA and encoding-CKA are reported correctly.
# - 1 pt: best-layer summary and model comparison are included.

# %% [markdown]
# ### 2.5 Compare predictive and representational metrics — 2 points
# - 1 pt: ranking comparison figure is present and informative.
# - 1 pt: agreement and disagreement between metrics are discussed clearly.

# %% [markdown]
# ### 2.6 Layer hierarchy vs brain hierarchy — 1 point
# - 1 pt: at least one hierarchy analysis is included and interpreted correctly.

# %% [markdown]
# ### 2.7 Compare the two feature extractors — 1 point
# - 1 pt: final comparison between Qwen3-VL and Adv-ResNet is clear and supported by results.

# %% [markdown]
# ## Section 3 — 30 points

# %% [markdown]
# ### Research question and motivation — 5 points
# - 2 pts: research question is clear and focused.
# - 3 pts: motivation is scientifically sensible and well connected to the baseline project.

# %% [markdown]
# ### Method and implementation — 10 points
# - 4 pts: the extension is described clearly.
# - 4 pts: the method is implemented correctly.
# - 2 pts: the design remains focused and technically appropriate for the project scope.

# %% [markdown]
# ### Baseline comparison and evaluation — 10 points
# - 4 pts: the comparison to the linear baseline is fair.
# - 3 pts: at least one figure or table communicates the comparison clearly.
# - 3 pts: evaluation supports the stated conclusion.

# %% [markdown]
# ### Interpretation and limitations — 5 points
# - 3 pts: the student explains whether the method helped in a practically meaningful way.
# - 2 pts: limitations or caveats are acknowledged.

# %% [markdown]
# ## Report — 30 points

# %% [markdown]
# ### Structure and clarity — 6 points
# - clear organization, readable flow, and concise scientific writing.

# %% [markdown]
# ### Selection of results — 6 points
# - the report focuses on the strongest and most relevant results rather than trying to include everything.

# %% [markdown]
# ### Methodological correctness — 6 points
# - metrics, comparisons, and claims are described accurately.

# %% [markdown]
# ### Interpretation and synthesis — 6 points
# - the report explains what the results mean and ties them back to the project goals.

# %% [markdown]
# ### Figure quality and presentation — 6 points
# - figures are readable, labeled, well-chosen, and integrated into the narrative.

# %% [markdown]
# ## Important grading note
#
# A submission that is technically correct but poorly interpreted will lose points. A submission with good intuition but missing required analyses will also lose points. The strongest submissions will be both **correct** and **scientifically well explained**.
#
# ---

# %% [markdown]
# # Final Checklist Before Submission
#
# Before submitting, make sure that:
#
# - group information is filled in,
# - the notebook runs from top to bottom,
# - all notebook outputs are cleared,
# - figures have readable titles and labels,
# - written answers are included in the answer boxes,
# - the zip archive name follows the required format,
# - no large unnecessary files are included.
#
# ---

# %% [markdown]
# # References
#
# Use the references below when you need scientific context for the datasets, models, and analysis methods.

# %% [markdown]
# ## Datasets
#
# - Papale et al. (2025) — *An extensive dataset of spiking activity to reveal the syntax of the ventral stream*
# - Gifford et al. (2022) — *A large and rich EEG dataset for modeling human visual object recognition*
# - Allen et al. (2022) — *A massive 7T fMRI dataset to bridge cognitive neuroscience and artificial intelligence*
# - van Bree, Styrnal, and Hebart (2025) — *How Much Variance Does Your Model Explain? A Clarifying Note On The Use Of Split-Half Reliability For Computing Noise Ceilings*

# %% [markdown]
# ## Models
#
# - Wong et al. (2020) — *Fast is better than free: Revisiting adversarial training*
# - He et al. (2016) — *Deep Residual Learning for Image Recognition*
# - Bai et al. (2025) — *Qwen3-VL Technical Report*

# %% [markdown]
# ## Alignment and encoding
#
# - Conwell et al. (2024) — *A large-scale examination of inductive biases shaping high-level visual representation in brains and machines*
# - Gokce and Schrimpf (2025) — *Scaling Laws for Task-Optimized Models of the Primate Visual Ventral Stream*
#
# Use these references selectively. You are not expected to read everything in full.
